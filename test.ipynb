# %%
# Appears like things don't work in a 
# python file but they do work in a notebook. 

"""Object Wrapper around SOFIMA on Zarr Datasets."""

from dataclasses import dataclass
from enum import Enum
import functools as ft
import jax
import jax.numpy as jnp
import numpy as np
import tensorstore as ts
import time

import zarr_io

from connectomics.common import bounding_box
from connectomics.common import box_generator
from connectomics.volume import subvolume
from sofima import stitch_rigid, flow_utils, stitch_elastic, mesh, map_utils

import coarse_registration
import fine_registration
import fusion
# ^All are forks


# NOTE:
# - SOFIMA/ZarrStitcher follows following basis convention:  
# o -- x
# |
# y
# Any reference to 'x' or 'y' adopt this basis. 

# - All displacements are defined in pixel space established 
# by the downsample_exp/resolution of the input images. 

# TODO: Consider moving to zarr_io -> 'zarr_utils'
class CloudStorage(Enum):
    """
    Documented Cloud Storage Options
    """
    S3 = 1
    GCS = 2


# TODO: Consider moving to zarr_io -> 'zarr_utils'
@dataclass
class ZarrDataset:
    """
    Parameters for locating Zarr dataset living on the cloud.
    """
    cloud_storage: CloudStorage
    bucket: str
    dataset_path: str
    tile_names: list[str]
    downsample_exp: int


# TODO: Consider moving to zarr_io -> 'zarr_utils'
def load_zarr_data(params: ZarrDataset
                   ) -> tuple[list[ts.TensorStore], tuple[int, int, int]]:
    """
    Reads Zarr dataset from input location 
    and returns list of equally-sized tensorstores
    in matching order as ZarrDataset.tile_names and tile size. 
    """
    
    def load_zarr(bucket: str, tile_location: str) -> ts.TensorStore:
        if params.cloud_storage == CloudStorage.S3:
            return zarr_io.open_zarr_s3(bucket, tile_location)
        else:  # cloud == 'gcs'
            return zarr_io.open_zarr_gcs(bucket, tile_location)
    tile_volumes = []
    min_x, min_y, min_z = np.inf, np.inf, np.inf
    for t_name in params.tile_names:
        tile_location = f"{params.dataset_path}/{t_name}/{params.downsample_exp}"
        tile = load_zarr(params.bucket, tile_location)
        tile_volumes.append(tile)
        
        _, _, tz, ty, tx = tile.shape
        min_x, min_y, min_z = int(np.minimum(min_x, tx)), \
                              int(np.minimum(min_y, ty)), \
                              int(np.minimum(min_z, tz))
    tile_size_xyz = min_x, min_y, min_z

    # Standardize size of tile volumes
    for i, tile_vol in enumerate(tile_volumes):
        tile_volumes[i] = tile_vol[:, :, :min_z, :min_y, :min_x]
        
    return tile_volumes, tile_size_xyz


class SyncAdapter:
  """Makes it possible to use a TensorStore objects as a numpy array."""
  
  def __init__(self, tstore):
    self.tstore = tstore

  def __getitem__(self, ind):
    print(ind)
    return np.array(self.tstore[ind])

  def __getattr__(self, attr):
    return getattr(self.tstore, attr)

  @property
  def shape(self):
    return self.tstore.shape

  @property
  def ndim(self):
    return self.tstore.ndim


class ZarrFusion(fusion.StitchAndRender3dTiles):
    """
    Fusion renderer subclass 
    that implements data loading for Zarr datasets.
    """
    cache = {}
    
    def __init__(self, 
                 zarr_params: ZarrDataset,
                 tile_layout: np.ndarray,
                 fine_tile_mesh: np.ndarray,
                 fine_mesh_xy_to_index: dict[tuple[int, int], int],
                 stride_zyx: tuple[int, int, int],
                 offset_xyz: tuple[float, float, float],
                 parallelism=16) -> None:
        super().__init__(tile_layout,
                       fine_tile_mesh,
                       fine_mesh_xy_to_index, 
                       stride_zyx,
                       offset_xyz,
                       parallelism)
        self.zarr_params = zarr_params
    

    def _open_tile_volume(self, tile_id: int):
        if tile_id in self.cache:
            return self.cache[tile_id]

        tile_volumes, tile_size_xyz = load_zarr_data(self.zarr_params)
        tile = tile_volumes[tile_id]
        self.cache[tile_id] = SyncAdapter(tile[0,0,:,:,:])
        return self.cache[tile_id]


class ZarrStitcher: 
    """
    Object wrapper around SOFIMA for operating on Zarr datasets.
    """

    def __init__(self,
                 input_zarr: ZarrDataset,
                 tile_layout: np.ndarray) -> None:
        """
        zarr_params: See ZarrDataset, params for input dataset
        tile_layout: 2D array of tile ids defining relative tile placement.
                     Tile ids correspond to indices of ZarrDataset.tile_names. 
        """

        self.input_zarr = input_zarr

        self.tile_volumes: list[ts.TensorStore] = []  # 5D tczyx homogenous shape
        self.tile_volumes, self.tile_size_xyz = load_zarr_data(input_zarr)
        self.tile_layout = tile_layout

        self.tile_map: dict[tuple[int, int], ts.TensorStore] = {}
        for y, row in enumerate(tile_layout):
            for x, tile_id in enumerate(row):
                self.tile_map[(x, y)] = self.tile_volumes[tile_id]


    def run_coarse_registration(self) -> tuple[np.ndarray, np.ndarray, np.ndarray]:
        """
        Runs coarse registration. 
        Returns: 
        cx: tile_layout shape
            Each entry represents displacement of current tile towards right neighbor.
        cy: tile_layout shape
            Each entry represents displacement of current tile towards bottom neighbor. 
        coarse_mesh: (3, 1, tile_layout) shape
            Each entry net displacement of current tile. 
        """

        # Custom data loading for coarse registration
        _tile_volumes: list[ts.TensorStore] = []
        for vol in self.tile_volumes:
            _tile_volumes.append(vol.T[:,:,:,0,0])

        cx, cy = coarse_registration.compute_coarse_offsets(self.tile_layout, 
                                                            _tile_volumes, 
                                                            False)  # TODO
        coarse_mesh = stitch_rigid.optimize_coarse_mesh(cx, 
                                                        cy, 
                                                        mesh_fn=stitch_rigid.elastic_tile_mesh_3d)
        return cx, cy, coarse_mesh


    def run_fine_registration(self, 
                              cx: np.ndarray, 
                              cy: np.ndarray, 
                              coarse_mesh: np.ndarray, 
                              stride_zyx: tuple[int, int, int]
                              ) -> tuple[np.ndarray, dict[tuple[int, int], int]]: 
        """
        Runs fine registration.
        Inputs:
        cx: Coarse offsets in x direction, output of coarse registration.
        cy: Coarse offsets in y direction, output of coarse registration.
        coarse_mesh: Coarse offsets in combined array, output of coarse registration.
        stride_zyx: Subdivision of each tile to create fine mesh. 

        Outputs:
        solved_fine_mesh: Fine mesh containing offsets of each subdivision.
            Shape is (3, tile_index, stride_z, stride_y, stride_x).
        fine_mesh_xy_to_index: Map of tile coordinates to custom mesh tile index.
        stride_zyx: Same as input, by returned as important parameter.
        """
        
        # Custom data loading for fine registration
        _tile_map = {}
        for key, tstore in self.tile_map.items(): 
            _tile_map[key] = SyncAdapter(tstore[0,:,:,:,:])

        # Compute flow map
        flow_x, offsets_x = fine_registration.compute_flow_map3d(_tile_map,
                                                                self.tile_size_xyz, 
                                                                cx, axis=0,
                                                                stride=stride_zyx,
                                                                patch_size=(80, 80, 80))

        flow_y, offsets_y = fine_registration.compute_flow_map3d(_tile_map,
                                                                self.tile_size_xyz, 
                                                                cy, axis=1,
                                                                stride=stride_zyx,
                                                                patch_size=(80, 80, 80))

        # Filter patch flows
        kwargs = {"min_peak_ratio": 1.4, "min_peak_sharpness": 1.4, "max_deviation": 5, "max_magnitude": 0, "dim": 3}
        fine_x = {k: flow_utils.clean_flow(v, **kwargs) for k, v in flow_x.items()}
        fine_y = {k: flow_utils.clean_flow(v, **kwargs) for k, v in flow_y.items()}

        kwargs = {"min_patch_size": 10, "max_gradient": -1, "max_deviation": -1}
        fine_x = {k: flow_utils.reconcile_flows([v], **kwargs) for k, v in fine_x.items()}
        fine_y = {k: flow_utils.reconcile_flows([v], **kwargs) for k, v in fine_y.items()}

        # Update mesh (convert coarse tile mesh into fine patch mesh)
        data_x = (cx[:, 0, ...], fine_x, offsets_x)
        data_y = (cy[:, 0, ...], fine_y, offsets_y)
        fx, fy, fine_mesh, nbors, fine_mesh_xy_to_index = stitch_elastic.aggregate_arrays(
            data_x, data_y, list(self.tile_map.keys()),
            coarse_mesh[:, 0, ...], stride=stride_zyx, tile_shape=self.tile_size_xyz[::-1])

        @jax.jit
        def prev_fn(x):
            target_fn = ft.partial(stitch_elastic.compute_target_mesh, x=x, fx=fx, fy=fy, stride=stride_zyx)
            x = jax.vmap(target_fn)(nbors)
            return jnp.transpose(x, [1, 0, 2, 3, 4])

        config = mesh.IntegrationConfig(dt=0.001, gamma=0., k0=0.01, k=0.1, stride=stride_zyx,
                                        num_iters=1000, max_iters=20000, stop_v_max=0.001,
                                        dt_max=100, prefer_orig_order=False,
                                        start_cap=0.1, final_cap=10., remove_drift=True)

        solved_fine_mesh, ekin, t = mesh.relax_mesh(fine_mesh, None, config, prev_fn=prev_fn, mesh_force=mesh.elastic_mesh_3d)

        return solved_fine_mesh, fine_mesh_xy_to_index, stride_zyx
    
    
    def _run_fusion(self, 
                    output_cloud_storage: CloudStorage,
                    output_bucket: str, 
                    output_path: str,
                    downsample_exp: int,
                    cx: np.ndarray, 
                    cy: np.ndarray, 
                    fine_mesh: np.ndarray, 
                    fine_mesh_xy_to_index: dict[tuple[int, int], int],
                    stride_zyx: tuple[int, int, int],
                    parallelism: int = 16
                    ) -> None: 
        """
        Runs fusion. 
        Inputs: 
        output_cloud_storage, output_bucket, output_path: 
            Output storage parameters  
        downsample_exp: 
            Desired output resolution, 0 for highest resolution.
        fine_mesh, fine_mesh_xy_to_index, stride_zyx:
            Fine mesh offsets and accompanying metadata, 
            output of coarse/fine registration.
        parallelism: 
            Multithreading. 
        """

        if output_cloud_storage == CloudStorage.S3:
            raise NotImplementedError(
                'TensorStore does not support s3 writes.'
            )

        fusion_zarr = self.input_zarr
        fusion_mesh = fine_mesh
        fusion_stride_zyx = stride_zyx
        fusion_tile_size_zyx = self.tile_size_xyz[::-1]
        if downsample_exp != self.input_zarr.downsample_exp:
            # Reload the data at target resolution
            fusion_zarr = ZarrDataset(self.input_zarr.cloud_storage,
                                       self.input_zarr.bucket,
                                       self.input_zarr.dataset_path, 
                                       self.input_zarr.tile_names,
                                       downsample_exp)

            # Rescale fine mesh, stride
            curr_exp = self.input_zarr.downsample_exp
            target_exp = downsample_exp
            scale_factor = 2**(curr_exp - target_exp)
            fusion_mesh = fine_mesh * scale_factor
            fusion_stride_zyx = tuple(np.array(stride_zyx) * scale_factor)
            fusion_tile_size_zyx = tuple(np.array(self.tile_size_xyz)[::-1] * scale_factor)
            print(f'{scale_factor=}')

        start = np.array([np.inf, np.inf, np.inf])
        map_box = bounding_box.BoundingBox(
            start=(0, 0, 0),
            size=fusion_mesh.shape[2:][::-1],
        )
        fine_mesh_index_to_xy = {
            v: k for k, v in fine_mesh_xy_to_index.items()
        }
        for i in range(0, fusion_mesh.shape[1]): 
            tx, ty = fine_mesh_index_to_xy[i]
            mesh = fusion_mesh[:, i, ...]
            tg_box = map_utils.outer_box(mesh, map_box, fusion_stride_zyx)

            out_box = bounding_box.BoundingBox(
                start=(
                tg_box.start[0] * fusion_stride_zyx[2] + tx * fusion_tile_size_zyx[2],
                tg_box.start[1] * fusion_stride_zyx[1] + ty * fusion_tile_size_zyx[1],
                tg_box.start[2] * fusion_stride_zyx[0],
                ),
                size=(
                tg_box.size[0] * fusion_stride_zyx[2],
                tg_box.size[1] * fusion_stride_zyx[1],
                tg_box.size[2] * fusion_stride_zyx[0],
                )
            )
            start = np.minimum(start, out_box.start)
            print(f'{tg_box=}')
            print(f'{out_box=}')  # TODO, Delete, Leaving in for now
        crop_offset = -start
        print(f'{crop_offset=}')

        # Fused shape
        cx[np.isnan(cx)] = 0    
        cy[np.isnan(cy)] = 0
        x_overlap = cx[2,0,0,0] / self.tile_size_xyz[0]
        y_overlap = cy[1,0,0,0] / self.tile_size_xyz[1]
        y_shape, x_shape = cx.shape[2], cx.shape[3]

        fused_x = fusion_tile_size_zyx[2] * (1 + ((x_shape - 1) * (1 - x_overlap)))
        fused_y = fusion_tile_size_zyx[1] * (1 + ((y_shape - 1) * (1 - y_overlap)))
        fused_z = fusion_tile_size_zyx[0]
        fused_shape_5d = [1, 1, int(fused_z), int(fused_y), int(fused_x)]
        print(f'{fused_shape_5d=}')

        # Perform fusion
        ds_out = zarr_io.write_zarr(output_bucket, fused_shape_5d, output_path)
        renderer = ZarrFusion(zarr_params=fusion_zarr, 
                              tile_layout=self.tile_layout, 
                              fine_tile_mesh=fusion_mesh, 
                              fine_mesh_xy_to_index=fine_mesh_xy_to_index,
                              stride_zyx=fusion_stride_zyx,
                              offset_xyz=crop_offset, 
                              parallelism=parallelism)

        box = bounding_box.BoundingBox(start=(0,0,0), size=ds_out.shape[4:1:-1])  # Needs xyz 
        gen = box_generator.BoxGenerator(box, (512, 512, 512), (0, 0, 0), True) # These are xyz
        renderer.set_effective_subvol_and_overlap((512, 512, 512), (0, 0, 0))
        for i, sub_box in enumerate(gen.boxes):
            t_start = time.time()

            # Feed in an empty subvol, with dimensions of sub_box. 
            inp_subvol = subvolume.Subvolume(np.zeros(sub_box.size[::-1], dtype=np.uint16)[None, ...], sub_box)
            ret_subvol = renderer.process(inp_subvol)  # czyx

            t_render = time.time()

            # ret_subvol is a 4D CZYX volume
            slice = ret_subvol.bbox.to_slice3d()
            slice = (0, 0, slice[0], slice[1], slice[2])
            ds_out[slice].write(ret_subvol.data[0, ...]).result()
            
            t_write = time.time()
            
            print('box {i}: {t1:0.2f} render  {t2:0.2f} write'.format(i=i, t1=t_render - t_start, t2=t_write - t_render))


    # def run_fusion_on_coarse_mesh(self, 
    #                               output_cloud_storage: CloudStorage,
    #                               output_bucket: str, 
    #                               output_path: str,
    #                               downsample_exp: int,
    #                               coarse_mesh: np.ndarray,
    #                               stride_zyx: tuple[int, int, int] = (20, 20, 20), 
    #                               parallelism: int = 16) -> None:
    #     """
    #     Transforms coarse mesh into fine mesh before 
    #     passing along to ZarrStitcher._run_fusion(...)
    #     """
 
    #     # Fine Mesh Tile Index
    #     fine_mesh_xy_to_index = {(tx, ty): i for i, (tx, ty) in enumerate(self.tile_map.keys())}

    #     # Fine Mesh
    #     dim = len(stride_zyx)
    #     mesh_shape = (np.array(self.tile_size_xyz[::-1]) // stride_zyx).tolist()
    #     fine_mesh = np.zeros([dim, len(fine_mesh_xy_to_index)] + mesh_shape, dtype=np.float32)
    #     for (tx, ty) in self.tile_map.keys(): 
    #         fine_mesh[:, fine_mesh_xy_to_index[tx, ty], ...] = coarse_mesh[:, 0, ty, tx].reshape(
    #         (dim,) + (1,) * dim)
    
    #     self._run_fusion(output_cloud_storage,
    #                     output_bucket, 
    #                     output_path,
    #                     downsample_exp,
    #                     fine_mesh, 
    #                     fine_mesh_xy_to_index,
    #                     stride_zyx,
    #                     parallelism)


    # def run_fusion_on_fine_mesh(self, 
    #                             output_cloud_storage: CloudStorage,
    #                             output_bucket: str, 
    #                             output_path: str,
    #                             downsample_exp: int,
    #                             fine_mesh: np.ndarray, 
    #                             fine_mesh_xy_to_index: dict[tuple[int, int], int],
    #                             stride_zyx: tuple[int, int, int],
    #                             parallelism: int = 16
    #                             ) -> None:
    #     """
    #     Simply passes all input parameters to 
    #     private method ZarrStitcher._run_fusion(...)
    #     """

    #     self._run_fusion(output_cloud_storage,
    #                     output_bucket, 
    #                     output_path,
    #                     downsample_exp,
    #                     fine_mesh, 
    #                     fine_mesh_xy_to_index,
    #                     stride_zyx,
    #                     parallelism)

# %%
# Application Inputs
cloud_storage = CloudStorage.S3
bucket = 'aind-open-data'
dataset_path = 'diSPIM_647459_2022-12-07_00-00-00/diSPIM.zarr'
downsample_exp = 2
tile_names = ['tile_X_0000_Y_0000_Z_0000_CH_0405_cam1.zarr', 
                'tile_X_0001_Y_0000_Z_0000_CH_0405_cam1.zarr']
tile_layout = np.array([[1],
                        [0]])
input_zarr = ZarrDataset(cloud_storage=cloud_storage,
                            bucket=bucket,
                            dataset_path=dataset_path, 
                            tile_names=tile_names,
                            downsample_exp=downsample_exp)

# Application Outputs
output_cloud_storage = CloudStorage.GCS
output_bucket = 'sofima-test-bucket'
output_path = 'output.zarr'   # This is your output name!

# SOFIMA, Low Res
zarr_stitcher = ZarrStitcher(input_zarr, tile_layout)
cx, cy, coarse_mesh = zarr_stitcher.run_coarse_registration()
stride_zyx = (20, 20, 20)
fine_mesh, fine_mesh_xy_to_index, stride_zyx = zarr_stitcher.run_fine_registration(cx, cy, coarse_mesh, stride_zyx)
np.savez_compressed('fine_mesh_data.npz',
                    fine_mesh=fine_mesh, 
                    fine_mesh_xy_to_index=fine_mesh_xy_to_index, 
                    stride_zyx=stride_zyx)

# %%
# Debugging
from connectomics.common import file

cloud_storage = CloudStorage.S3
bucket = 'aind-open-data'
dataset_path = 'diSPIM_647459_2022-12-07_00-00-00/diSPIM.zarr'
downsample_exp = 2
tile_names = ['tile_X_0000_Y_0000_Z_0000_CH_0405_cam1.zarr', 
                'tile_X_0001_Y_0000_Z_0000_CH_0405_cam1.zarr']
tile_layout = np.array([[1],
                        [0]])
input_zarr = ZarrDataset(cloud_storage=cloud_storage,
                            bucket=bucket,
                            dataset_path=dataset_path, 
                            tile_names=tile_names,
                            downsample_exp=downsample_exp)

# Application Outputs
output_cloud_storage = CloudStorage.GCS
output_bucket = 'sofima-test-bucket'
output_path = 'output_level_0.zarr'   # This is your output name!


data_path = 'fine_mesh_data.npz'
with file.Open(data_path, 'rb') as f:
    data = np.load(f, allow_pickle=True)
fine_mesh = data['fine_mesh']
fine_mesh_xy_to_index = data['fine_mesh_xy_to_index'].item()
stride_zyx = tuple(data['stride_zyx'])

zarr_stitcher = ZarrStitcher(input_zarr, tile_layout)
cx, cy, coarse_mesh = zarr_stitcher.run_coarse_registration()
zarr_stitcher._run_fusion(output_cloud_storage=output_cloud_storage,
                        output_bucket=output_bucket,
                        output_path=output_path,
                        downsample_exp=0,
                        cx=cx,
                        cy=cy,
                        fine_mesh=fine_mesh,
                        fine_mesh_xy_to_index=fine_mesh_xy_to_index,
                        stride_zyx=stride_zyx)
# Out:
# Top Id: 1, Bottom Id: 0
# Top: (0, 0), Bot: (1, 0) [ -1. 285.  -4.]
# tg_box=BoundingBox(start=(0, 7, 0), size=(29, 29, 178), is_border_start=(False, False, False), is_border_end=(False, False, False))
# out_box=BoundingBox(start=(0, 560, 0), size=(2320, 2320, 14240), is_border_start=(False, False, False), is_border_end=(False, False, False))
# tg_box=BoundingBox(start=(-1, -8, -1), size=(30, 29, 178), is_border_start=(False, False, False), is_border_end=(False, False, False))
# out_box=BoundingBox(start=(-80, 1664, -80), size=(2400, 2320, 14240), is_border_start=(False, False, False), is_border_end=(False, False, False))
# (slice(0, 556, None), slice(180, 902, None), slice(0, 559, None))
# (slice(0, 566, None), slice(0, 290, None), slice(0, 565, None))
# box 0: 36.18 render  0.36 write
# (slice(0, 556, None), slice(180, 903, None), slice(237, 1039, None))
# (slice(0, 568, None), slice(0, 289, None), slice(240, 1046, None))
# box 1: 35.82 render  0.47 write
# (slice(0, 557, None), slice(181, 904, None), slice(717, 1152, None))
# (slice(0, 568, None), slice(0, 290, None), slice(721, 1152, None))
# box 2: 34.46 render  0.30 write
# box 3: 0.24 render  0.05 write
# box 4: 0.24 render  0.04 write
# (slice(0, 556, None), slice(580, 1152, None), slice(0, 559, None))
# (slice(0, 567, None), slice(46, 848, None), slice(0, 565, None))
# box 5: 34.76 render  0.42 write
# (slice(0, 556, None), slice(580, 1152, None), slice(236, 1039, None))
# (slice(0, 568, None), slice(44, 849, None), slice(241, 1046, None))
# box 6: 36.07 render  0.41 write
# (slice(0, 556, None), slice(581, 1152, None), slice(716, 1152, None))
# (slice(0, 568, None), slice(44, 850, None), slice(721, 1152, None))
# box 7: 33.31 render  0.42 write
# box 8: 0.24 render  0.05 write
# box 9: 0.24 render  0.04 write
# (slice(0, 556, None), slice(1060, 1152, None), slice(0, 558, None))
# (slice(0, 567, None), slice(525, 1152, None), slice(0, 565, None))
# box 10: 32.90 render  0.35 write
# (slice(0, 556, None), slice(1060, 1152, None), slice(235, 1039, None))
# (slice(0, 567, None), slice(525, 1152, None), slice(241, 1043, None))
# box 11: 33.25 render  0.45 write
# (slice(0, 557, None), slice(1061, 1152, None), slice(714, 1152, None))
# (slice(0, 567, None), slice(525, 1152, None), slice(720, 1152, None))
# box 12: 31.01 render  0.24 write
# box 13: 0.24 render  0.05 write
# box 14: 0.24 render  0.04 write
# (slice(0, 564, None), slice(1005, 1152, None), slice(0, 563, None))
# box 15: 15.71 render  0.17 write
# (slice(0, 564, None), slice(1006, 1152, None), slice(240, 1042, None))
# box 16: 17.07 render  0.14 write
# (slice(0, 564, None), slice(1007, 1152, None), slice(719, 1152, None))
# box 17: 17.32 render  0.18 write
# box 18: 0.24 render  0.04 write
# box 19: 0.24 render  0.05 write
# box 20: 0.30 render  0.07 write
# box 21: 0.24 render  0.05 write
# box 22: 0.24 render  0.04 write
# box 23: 0.24 render  0.04 write
# box 24: 0.24 render  0.05 write
# box 25: 0.24 render  0.04 write
# box 26: 0.24 render  0.04 write
# box 27: 0.24 render  0.05 write
# box 28: 0.24 render  0.05 write
# box 29: 0.24 render  0.08 write
# box 30: 0.24 render  0.05 write
# box 31: 0.24 render  0.04 write
# box 32: 0.24 render  0.04 write
# box 33: 0.26 render  0.04 write
# box 34: 0.26 render  0.04 write
# box 35: 0.26 render  0.04 write
# box 36: 0.25 render  0.04 write
# box 37: 0.25 render  0.04 write
# box 38: 0.24 render  0.04 write
# box 39: 0.24 render  0.04 write
# box 40: 0.24 render  0.11 write
# box 41: 0.24 render  0.12 write
# box 42: 0.24 render  0.12 write
# box 43: 0.24 render  0.11 write
# box 44: 0.24 render  0.22 write
# (slice(234, 1036, None), slice(180, 903, None), slice(0, 559, None))
# (slice(242, 1046, None), slice(0, 291, None), slice(0, 565, None))
# box 45: 38.74 render  0.43 write
# (slice(234, 1036, None), slice(181, 904, None), slice(237, 1039, None))
# (slice(243, 1048, None), slice(0, 290, None), slice(240, 1046, None))
# box 46: 40.01 render  0.52 write
# (slice(234, 1037, None), slice(182, 904, None), slice(717, 1152, None))
# (slice(241, 1048, None), slice(0, 291, None), slice(721, 1152, None))
# box 47: 34.03 render  0.36 write
# box 48: 0.24 render  0.04 write
# box 49: 0.24 render  0.04 write
# (slice(234, 1036, None), slice(580, 1152, None), slice(0, 559, None))
# (slice(242, 1045, None), slice(47, 850, None), slice(0, 565, None))
# box 50: 36.78 render  0.50 write
# (slice(233, 1036, None), slice(581, 1152, None), slice(236, 1039, None))
# (slice(242, 1048, None), slice(45, 850, None), slice(240, 1046, None))
# box 51: 39.68 render  0.40 write
# (slice(233, 1036, None), slice(582, 1152, None), slice(716, 1152, None))
# (slice(241, 1048, None), slice(45, 851, None), slice(722, 1152, None))
# box 52: 34.22 render  0.31 write
# box 53: 0.24 render  0.06 write
# box 54: 0.24 render  0.05 write
# (slice(232, 1036, None), slice(1060, 1152, None), slice(0, 558, None))
# (slice(242, 1045, None), slice(525, 1152, None), slice(0, 565, None))
# box 55: 33.56 render  0.43 write
# (slice(231, 1036, None), slice(1060, 1152, None), slice(236, 1038, None))
# (slice(241, 1046, None), slice(525, 1152, None), slice(241, 1044, None))
# box 56: 33.75 render  0.41 write
# (slice(231, 1036, None), slice(1061, 1152, None), slice(714, 1152, None))
# (slice(240, 1046, None), slice(526, 1152, None), slice(720, 1152, None))
# box 57: 31.92 render  0.31 write
# box 58: 0.24 render  0.05 write
# box 59: 0.24 render  0.04 write
# (slice(241, 1044, None), slice(1006, 1152, None), slice(0, 564, None))
# box 60: 15.62 render  0.17 write
# (slice(241, 1044, None), slice(1006, 1152, None), slice(240, 1043, None))
# box 61: 16.19 render  0.13 write
# (slice(240, 1044, None), slice(1007, 1152, None), slice(720, 1152, None))
# box 62: 15.44 render  0.18 write
# box 63: 0.24 render  0.05 write
# box 64: 0.24 render  0.04 write
# box 65: 0.24 render  0.05 write
# box 66: 0.24 render  0.05 write
# box 67: 0.24 render  0.05 write
# box 68: 0.24 render  0.07 write
# box 69: 0.24 render  0.05 write
# box 70: 0.24 render  0.04 write
# box 71: 0.24 render  0.06 write
# box 72: 0.24 render  0.04 write
# box 73: 0.24 render  0.04 write
# box 74: 0.24 render  0.04 write
# box 75: 0.24 render  0.05 write
# box 76: 0.24 render  0.04 write
# box 77: 0.24 render  0.04 write
# box 78: 0.24 render  0.04 write
# box 79: 0.24 render  0.04 write
# box 80: 0.24 render  0.04 write
# box 81: 0.24 render  0.05 write
# box 82: 0.24 render  0.05 write
# box 83: 0.24 render  0.05 write
# box 84: 0.24 render  0.05 write
# box 85: 0.24 render  0.12 write
# box 86: 0.24 render  0.11 write
# box 87: 0.24 render  0.13 write
# box 88: 0.26 render  0.11 write
# box 89: 0.24 render  0.15 write
# (slice(714, 1516, None), slice(181, 903, None), slice(0, 559, None))
# (slice(723, 1525, None), slice(0, 292, None), slice(0, 564, None))
# box 90: 38.32 render  0.42 write
# (slice(714, 1516, None), slice(181, 904, None), slice(237, 1039, None))
# (slice(723, 1528, None), slice(0, 292, None), slice(240, 1046, None))
# box 91: 36.91 render  0.44 write
# (slice(714, 1517, None), slice(182, 905, None), slice(717, 1152, None))
# (slice(721, 1528, None), slice(0, 291, None), slice(721, 1152, None))
# box 92: 34.49 render  0.28 write
# box 93: 0.29 render  0.04 write
# box 94: 0.24 render  0.05 write
# (slice(714, 1516, None), slice(581, 1152, None), slice(0, 559, None))
# (slice(723, 1524, None), slice(48, 851, None), slice(0, 565, None))
# box 95: 36.28 render  0.40 write
# (slice(713, 1516, None), slice(581, 1152, None), slice(237, 1039, None))
# (slice(723, 1528, None), slice(45, 851, None), slice(240, 1046, None))
# box 96: 38.01 render  0.43 write
# (slice(713, 1516, None), slice(582, 1152, None), slice(716, 1152, None))
# (slice(721, 1528, None), slice(45, 851, None), slice(722, 1152, None))
# box 97: 33.27 render  0.30 write
# box 98: 0.24 render  0.04 write
# box 99: 0.24 render  0.04 write
# (slice(713, 1516, None), slice(1060, 1152, None), slice(0, 558, None))
# (slice(722, 1524, None), slice(527, 1152, None), slice(0, 565, None))
# box 100: 33.42 render  0.43 write
# (slice(711, 1516, None), slice(1061, 1152, None), slice(237, 1038, None))
# (slice(722, 1527, None), slice(526, 1152, None), slice(241, 1046, None))
# box 101: 34.28 render  0.36 write
# (slice(711, 1516, None), slice(1062, 1152, None), slice(714, 1152, None))
# (slice(720, 1527, None), slice(526, 1152, None), slice(721, 1152, None))
# box 102: 31.59 render  0.25 write
# box 103: 0.24 render  0.05 write
# box 104: 0.24 render  0.05 write
# (slice(721, 1524, None), slice(1008, 1152, None), slice(0, 564, None))
# box 105: 17.76 render  0.18 write
# (slice(721, 1524, None), slice(1008, 1152, None), slice(241, 1043, None))
# box 106: 16.81 render  0.10 write
# (slice(720, 1524, None), slice(1008, 1152, None), slice(720, 1152, None))
# box 107: 15.94 render  0.17 write
# box 108: 0.24 render  0.04 write
# box 109: 0.24 render  0.05 write
# box 110: 0.24 render  0.05 write
# box 111: 0.24 render  0.05 write
# box 112: 0.24 render  0.05 write
# box 113: 0.24 render  0.04 write
# box 114: 0.24 render  0.04 write
# box 115: 0.24 render  0.04 write
# box 116: 0.24 render  0.04 write
# box 117: 0.24 render  0.04 write
# box 118: 0.24 render  0.04 write
# box 119: 0.24 render  0.04 write
# box 120: 0.24 render  0.05 write
# box 121: 0.24 render  0.04 write
# box 122: 0.24 render  0.04 write
# box 123: 0.23 render  0.04 write
# box 124: 0.24 render  0.04 write
# box 125: 0.24 render  0.04 write
# box 126: 0.24 render  0.06 write
# box 127: 0.24 render  0.04 write
# box 128: 0.24 render  0.08 write
# box 129: 0.24 render  0.04 write
# box 130: 0.24 render  0.12 write
# box 131: 0.24 render  0.10 write
# box 132: 0.24 render  0.11 write
# box 133: 0.24 render  0.11 write
# box 134: 0.24 render  0.14 write
# (slice(1275, 2077, None), slice(181, 904, None), slice(0, 559, None))
# (slice(1282, 2084, None), slice(0, 294, None), slice(0, 563, None))
# box 135: 36.62 render  0.39 write
# (slice(1275, 2077, None), slice(182, 905, None), slice(237, 1039, None))
# (slice(1282, 2087, None), slice(0, 294, None), slice(241, 1047, None))
# box 136: 36.94 render  0.43 write
# (slice(1275, 2077, None), slice(182, 905, None), slice(717, 1152, None))
# (slice(1282, 2087, None), slice(0, 291, None), slice(721, 1152, None))
# box 137: 34.51 render  0.30 write
# box 138: 0.24 render  0.04 write
# box 139: 0.24 render  0.04 write
# (slice(1274, 2077, None), slice(581, 1152, None), slice(0, 559, None))
# (slice(1282, 2084, None), slice(50, 853, None), slice(0, 565, None))
# box 140: 36.71 render  0.43 write
# (slice(1273, 2077, None), slice(581, 1152, None), slice(237, 1038, None))
# (slice(1282, 2087, None), slice(46, 852, None), slice(241, 1047, None))
# box 141: 37.13 render  0.37 write
# (slice(1273, 2076, None), slice(582, 1152, None), slice(716, 1152, None))
# (slice(1281, 2087, None), slice(46, 852, None), slice(722, 1152, None))
# box 142: 34.59 render  0.27 write
# box 143: 0.24 render  0.05 write
# box 144: 0.24 render  0.04 write
# (slice(1274, 2076, None), slice(1061, 1152, None), slice(0, 558, None))
# (slice(1282, 2083, None), slice(528, 1152, None), slice(0, 565, None))
# box 145: 34.35 render  0.51 write
# (slice(1271, 2076, None), slice(1061, 1152, None), slice(236, 1038, None))
# (slice(1282, 2087, None), slice(527, 1152, None), slice(241, 1046, None))
# box 146: 33.33 render  0.38 write
# (slice(1271, 2076, None), slice(1062, 1152, None), slice(715, 1152, None))
# (slice(1281, 2087, None), slice(527, 1152, None), slice(722, 1152, None))
# box 147: 34.54 render  0.32 write
# box 148: 0.24 render  0.05 write
# box 149: 0.24 render  0.05 write
# (slice(1281, 2083, None), slice(1008, 1152, None), slice(0, 565, None))
# box 150: 17.87 render  0.18 write
# (slice(1281, 2084, None), slice(1008, 1152, None), slice(242, 1044, None))
# box 151: 15.76 render  0.14 write
# (slice(1280, 2084, None), slice(1009, 1152, None), slice(722, 1152, None))
# box 152: 16.22 render  0.18 write
# box 153: 0.24 render  0.05 write
# box 154: 0.25 render  0.05 write
# box 155: 0.25 render  0.09 write
# box 156: 0.24 render  0.04 write
# box 157: 0.24 render  0.04 write
# box 158: 0.24 render  0.05 write
# box 159: 0.24 render  0.04 write
# box 160: 0.24 render  0.04 write
# box 161: 0.24 render  0.04 write
# box 162: 0.24 render  0.04 write
# box 163: 0.24 render  0.04 write
# box 164: 0.24 render  0.05 write
# box 165: 0.24 render  0.04 write
# box 166: 0.24 render  0.04 write
# box 167: 0.24 render  0.04 write
# box 168: 0.24 render  0.05 write
# box 169: 0.24 render  0.05 write
# box 170: 0.24 render  0.04 write
# box 171: 0.24 render  0.04 write
# box 172: 0.24 render  0.04 write
# box 173: 0.24 render  0.05 write
# box 174: 0.24 render  0.04 write
# box 175: 0.24 render  0.15 write
# box 176: 0.24 render  0.13 write
# box 177: 0.23 render  0.12 write
# box 178: 0.24 render  0.13 write
# box 179: 0.24 render  0.11 write
# (slice(1755, 2557, None), slice(182, 904, None), slice(0, 559, None))
# (slice(1762, 2564, None), slice(0, 294, None), slice(0, 563, None))
# box 180: 36.41 render  0.41 write
# (slice(1755, 2557, None), slice(182, 905, None), slice(237, 1039, None))
# (slice(1762, 2567, None), slice(0, 294, None), slice(240, 1047, None))
# box 181: 36.87 render  0.69 write
# (slice(1755, 2557, None), slice(183, 906, None), slice(717, 1152, None))
# (slice(1762, 2567, None), slice(0, 292, None), slice(721, 1152, None))
# box 182: 34.24 render  0.28 write
# box 183: 0.24 render  0.04 write
# box 184: 0.24 render  0.04 write
# (slice(1754, 2557, None), slice(582, 1152, None), slice(0, 559, None))
# (slice(1762, 2563, None), slice(51, 854, None), slice(0, 565, None))
# box 185: 36.69 render  0.45 write
# (slice(1753, 2557, None), slice(582, 1152, None), slice(237, 1039, None))
# (slice(1762, 2567, None), slice(47, 853, None), slice(240, 1047, None))
# box 186: 39.51 render  0.45 write
# (slice(1753, 2557, None), slice(583, 1152, None), slice(717, 1152, None))
# (slice(1761, 2567, None), slice(47, 852, None), slice(722, 1152, None))
# box 187: 33.62 render  0.31 write
# box 188: 0.24 render  0.05 write
# box 189: 0.24 render  0.04 write
# (slice(1754, 2557, None), slice(1062, 1152, None), slice(0, 558, None))
# (slice(1762, 2563, None), slice(530, 1152, None), slice(0, 565, None))
# box 190: 33.68 render  0.37 write
# (slice(1750, 2557, None), slice(1062, 1152, None), slice(236, 1038, None))
# (slice(1762, 2567, None), slice(527, 1152, None), slice(241, 1046, None))
# box 191: 34.04 render  0.50 write
# (slice(1750, 2556, None), slice(1063, 1152, None), slice(715, 1152, None))
# (slice(1761, 2567, None), slice(527, 1152, None), slice(723, 1152, None))
# box 192: 34.08 render  0.26 write
# box 193: 0.24 render  0.05 write
# box 194: 0.24 render  0.04 write
# (slice(1761, 2563, None), slice(1009, 1152, None), slice(0, 565, None))
# box 195: 17.47 render  0.20 write
# (slice(1761, 2564, None), slice(1009, 1152, None), slice(243, 1044, None))
# box 196: 15.99 render  0.14 write
# (slice(1761, 2564, None), slice(1009, 1152, None), slice(722, 1152, None))
# box 197: 15.38 render  0.17 write
# box 198: 0.24 render  0.04 write
# box 199: 0.24 render  0.08 write
# box 200: 0.24 render  0.04 write
# box 201: 0.24 render  0.05 write
# box 202: 0.24 render  0.05 write
# box 203: 0.24 render  0.05 write
# box 204: 0.24 render  0.04 write
# box 205: 0.24 render  0.05 write
# box 206: 0.24 render  0.04 write
# box 207: 0.24 render  0.05 write
# box 208: 0.24 render  0.04 write
# box 209: 0.24 render  0.04 write
# box 210: 0.24 render  0.04 write
# box 211: 0.24 render  0.04 write
# box 212: 0.24 render  0.04 write
# box 213: 0.24 render  0.04 write
# box 214: 0.24 render  0.04 write
# box 215: 0.24 render  0.04 write
# box 216: 0.24 render  0.04 write
# box 217: 0.24 render  0.04 write
# box 218: 0.24 render  0.04 write
# box 219: 0.24 render  0.04 write
# box 220: 0.24 render  0.15 write
# box 221: 0.24 render  0.12 write
# box 222: 0.24 render  0.11 write
# box 223: 0.24 render  0.13 write
# box 224: 0.24 render  0.11 write
# (slice(2315, 3117, None), slice(182, 905, None), slice(0, 559, None))
# (slice(2321, 3123, None), slice(0, 295, None), slice(0, 563, None))
# box 225: 36.30 render  0.43 write
# (slice(2315, 3117, None), slice(183, 905, None), slice(237, 1039, None))
# (slice(2321, 3127, None), slice(0, 294, None), slice(240, 1046, None))
# box 226: 37.39 render  0.46 write
# (slice(2315, 3117, None), slice(183, 906, None), slice(717, 1152, None))
# (slice(2323, 3127, None), slice(0, 293, None), slice(720, 1152, None))
# box 227: 35.48 render  0.30 write
# box 228: 0.24 render  0.04 write
# box 229: 0.24 render  0.08 write
# (slice(2315, 3117, None), slice(582, 1152, None), slice(0, 559, None))
# (slice(2321, 3123, None), slice(52, 854, None), slice(0, 565, None))
# box 230: 36.06 render  0.43 write
# (slice(2314, 3117, None), slice(583, 1152, None), slice(237, 1039, None))
# (slice(2321, 3127, None), slice(48, 853, None), slice(240, 1046, None))
# box 231: 38.23 render  0.41 write
# (slice(2313, 3117, None), slice(583, 1152, None), slice(717, 1152, None))
# (slice(2322, 3127, None), slice(47, 852, None), slice(721, 1152, None))
# box 232: 33.69 render  0.34 write
# box 233: 0.24 render  0.04 write
# box 234: 0.24 render  0.04 write
# (slice(2315, 3117, None), slice(1062, 1152, None), slice(0, 558, None))
# (slice(2321, 3123, None), slice(531, 1152, None), slice(0, 565, None))
# box 235: 35.65 render  0.39 write
# (slice(2311, 3117, None), slice(1063, 1152, None), slice(237, 1038, None))
# (slice(2321, 3126, None), slice(528, 1152, None), slice(241, 1046, None))
# box 236: 35.85 render  0.46 write
# (slice(2311, 3116, None), slice(1063, 1152, None), slice(716, 1152, None))
# (slice(2321, 3126, None), slice(528, 1152, None), slice(723, 1152, None))
# box 237: 34.30 render  0.23 write
# box 238: 0.24 render  0.07 write
# box 239: 0.25 render  0.06 write
# (slice(2321, 3123, None), slice(1010, 1152, None), slice(0, 565, None))
# box 240: 16.06 render  0.18 write
# (slice(2321, 3124, None), slice(1010, 1152, None), slice(243, 1044, None))
# box 241: 16.58 render  0.15 write
# (slice(2321, 3124, None), slice(1010, 1152, None), slice(723, 1152, None))
# box 242: 15.93 render  0.18 write
# box 243: 0.24 render  0.06 write
# box 244: 0.24 render  0.04 write
# box 245: 0.25 render  0.05 write
# box 246: 0.24 render  0.05 write
# box 247: 0.24 render  0.05 write
# box 248: 0.24 render  0.05 write
# box 249: 0.30 render  0.05 write
# box 250: 0.24 render  0.05 write
# box 251: 0.24 render  0.05 write
# box 252: 0.24 render  0.06 write
# box 253: 0.24 render  0.05 write
# box 254: 0.24 render  0.04 write
# box 255: 0.24 render  0.04 write
# box 256: 0.24 render  0.04 write
# box 257: 0.24 render  0.04 write
# box 258: 0.24 render  0.09 write
# box 259: 0.24 render  0.04 write
# box 260: 0.24 render  0.04 write
# box 261: 0.24 render  0.06 write
# box 262: 0.24 render  0.04 write
# box 263: 0.24 render  0.04 write
# box 264: 0.24 render  0.04 write
# box 265: 0.24 render  0.12 write
# box 266: 0.24 render  0.11 write
# box 267: 0.24 render  0.16 write
# box 268: 0.23 render  0.12 write
# box 269: 0.24 render  0.11 write
# (slice(2796, 3597, None), slice(183, 905, None), slice(0, 559, None))
# (slice(2801, 3603, None), slice(0, 295, None), slice(0, 562, None))
# box 270: 37.80 render  0.43 write
# (slice(2795, 3597, None), slice(183, 906, None), slice(238, 1039, None))
# (slice(2801, 3606, None), slice(0, 295, None), slice(240, 1046, None))
# box 271: 37.14 render  0.45 write
# (slice(2795, 3597, None), slice(184, 907, None), slice(717, 1152, None))
# (slice(2803, 3606, None), slice(0, 293, None), slice(720, 1152, None))
# box 272: 36.03 render  0.31 write
# box 273: 0.24 render  0.05 write
# box 274: 0.25 render  0.05 write
# (slice(2795, 3597, None), slice(583, 1152, None), slice(0, 559, None))
# (slice(2801, 3602, None), slice(53, 855, None), slice(0, 564, None))
# box 275: 36.48 render  0.43 write
# (slice(2794, 3597, None), slice(583, 1152, None), slice(237, 1039, None))
# (slice(2801, 3606, None), slice(49, 854, None), slice(240, 1046, None))
# box 276: 38.16 render  0.54 write
# (slice(2794, 3597, None), slice(584, 1152, None), slice(717, 1152, None))
# (slice(2802, 3606, None), slice(48, 853, None), slice(721, 1152, None))
# box 277: 33.66 render  0.28 write
# box 278: 0.24 render  0.04 write
# box 279: 0.24 render  0.04 write
# (slice(2795, 3598, None), slice(1063, 1152, None), slice(0, 559, None))
# (slice(2801, 3602, None), slice(531, 1152, None), slice(0, 564, None))
# box 280: 33.80 render  0.35 write
# (slice(2791, 3598, None), slice(1063, 1152, None), slice(237, 1038, None))
# (slice(2801, 3606, None), slice(529, 1152, None), slice(240, 1046, None))
# box 281: 32.80 render  0.40 write
# (slice(2791, 3597, None), slice(1064, 1152, None), slice(716, 1152, None))
# (slice(2802, 3606, None), slice(529, 1152, None), slice(722, 1152, None))
# box 282: 32.60 render  0.28 write
# box 283: 0.24 render  0.07 write
# box 284: 0.24 render  0.04 write
# (slice(2801, 3602, None), slice(1011, 1152, None), slice(0, 564, None))
# box 285: 15.50 render  0.17 write
# (slice(2801, 3603, None), slice(1010, 1152, None), slice(242, 1044, None))
# box 286: 16.38 render  0.10 write
# (slice(2801, 3603, None), slice(1010, 1152, None), slice(723, 1152, None))
# box 287: 17.15 render  0.18 write
# box 288: 0.24 render  0.04 write
# box 289: 0.24 render  0.05 write
# box 290: 0.24 render  0.05 write
# box 291: 0.24 render  0.05 write
# box 292: 0.24 render  0.04 write
# box 293: 0.31 render  0.04 write
# box 294: 0.24 render  0.04 write
# box 295: 0.24 render  0.05 write
# box 296: 0.24 render  0.04 write
# box 297: 0.24 render  0.04 write
# box 298: 0.24 render  0.04 write
# box 299: 0.24 render  0.04 write
# box 300: 0.24 render  0.04 write
# box 301: 0.24 render  0.04 write
# box 302: 0.24 render  0.05 write
# box 303: 0.24 render  0.04 write
# box 304: 0.24 render  0.04 write
# box 305: 0.24 render  0.05 write
# box 306: 0.24 render  0.07 write
# box 307: 0.24 render  0.05 write
# box 308: 0.24 render  0.04 write
# box 309: 0.24 render  0.04 write
# box 310: 0.24 render  0.16 write
# box 311: 0.24 render  0.10 write
# box 312: 0.24 render  0.10 write
# box 313: 0.24 render  0.12 write
# box 314: 0.24 render  0.12 write
# (slice(3276, 4078, None), slice(183, 905, None), slice(0, 559, None))
# (slice(3281, 4083, None), slice(0, 295, None), slice(0, 562, None))
# box 315: 35.23 render  0.40 write
# (slice(3275, 4078, None), slice(184, 906, None), slice(238, 1039, None))
# (slice(3281, 4086, None), slice(0, 295, None), slice(240, 1045, None))
# box 316: 37.26 render  0.46 write
# (slice(3275, 4077, None), slice(184, 907, None), slice(718, 1152, None))
# (slice(3282, 4086, None), slice(0, 294, None), slice(720, 1152, None))
# box 317: 33.54 render  0.39 write
# box 318: 0.24 render  0.04 write
# box 319: 0.24 render  0.04 write
# (slice(3276, 4077, None), slice(583, 1152, None), slice(0, 559, None))
# (slice(3281, 4083, None), slice(53, 855, None), slice(0, 564, None))
# box 320: 37.11 render  0.41 write
# (slice(3274, 4077, None), slice(584, 1152, None), slice(237, 1039, None))
# (slice(3281, 4086, None), slice(50, 854, None), slice(240, 1046, None))
# box 321: 38.04 render  0.40 write
# (slice(3274, 4077, None), slice(584, 1152, None), slice(717, 1152, None))
# (slice(3282, 4086, None), slice(48, 853, None), slice(721, 1152, None))
# box 322: 36.55 render  0.30 write
# box 323: 0.25 render  0.05 write
# box 324: 0.25 render  0.05 write
# (slice(3276, 4078, None), slice(1063, 1152, None), slice(0, 559, None))
# (slice(3281, 4083, None), slice(532, 1152, None), slice(0, 564, None))
# box 325: 32.50 render  0.54 write
# (slice(3272, 4078, None), slice(1064, 1152, None), slice(237, 1038, None))
# (slice(3281, 4086, None), slice(530, 1152, None), slice(240, 1046, None))
# box 326: 34.61 render  0.45 write
# (slice(3272, 4077, None), slice(1064, 1152, None), slice(717, 1152, None))
# (slice(3282, 4086, None), slice(530, 1152, None), slice(722, 1152, None))
# box 327: 33.55 render  0.27 write
# box 328: 0.24 render  0.05 write
# box 329: 0.24 render  0.04 write
# (slice(3281, 4083, None), slice(1011, 1152, None), slice(0, 564, None))
# box 330: 15.98 render  0.17 write
# (slice(3281, 4083, None), slice(1011, 1152, None), slice(242, 1044, None))
# box 331: 15.88 render  0.13 write
# (slice(3281, 4084, None), slice(1011, 1152, None), slice(723, 1152, None))
# box 332: 16.21 render  0.18 write
# box 333: 0.24 render  0.05 write
# box 334: 0.24 render  0.04 write
# box 335: 0.25 render  0.05 write
# box 336: 0.24 render  0.04 write
# box 337: 0.24 render  0.05 write
# box 338: 0.24 render  0.05 write
# box 339: 0.24 render  0.04 write
# box 340: 0.24 render  0.05 write
# box 341: 0.24 render  0.04 write
# box 342: 0.24 render  0.05 write
# box 343: 0.24 render  0.05 write
# box 344: 0.24 render  0.04 write
# box 345: 0.24 render  0.04 write
# box 346: 0.24 render  0.05 write
# box 347: 0.24 render  0.04 write
# box 348: 0.24 render  0.04 write
# box 349: 0.24 render  0.04 write
# box 350: 0.24 render  0.04 write
# box 351: 0.24 render  0.04 write
# box 352: 0.24 render  0.05 write
# box 353: 0.24 render  0.04 write
# box 354: 0.24 render  0.04 write
# box 355: 0.24 render  0.13 write
# box 356: 0.24 render  0.12 write
# box 357: 0.24 render  0.12 write
# box 358: 0.24 render  0.15 write
# box 359: 0.24 render  0.12 write
# (slice(3836, 4638, None), slice(184, 906, None), slice(0, 559, None))
# (slice(3841, 4643, None), slice(0, 296, None), slice(0, 562, None))
# box 360: 35.64 render  0.39 write
# (slice(3836, 4638, None), slice(184, 906, None), slice(238, 1039, None))
# (slice(3841, 4646, None), slice(0, 296, None), slice(240, 1045, None))
# box 361: 38.50 render  0.45 write
# (slice(3836, 4638, None), slice(185, 907, None), slice(718, 1152, None))
# (slice(3842, 4646, None), slice(0, 294, None), slice(720, 1152, None))
# box 362: 33.48 render  0.41 write
# box 363: 0.24 render  0.04 write
# box 364: 0.24 render  0.04 write
# (slice(3836, 4638, None), slice(584, 1152, None), slice(0, 559, None))
# (slice(3841, 4643, None), slice(54, 855, None), slice(0, 563, None))
# box 365: 37.71 render  0.42 write
# (slice(3835, 4638, None), slice(584, 1152, None), slice(237, 1039, None))
# (slice(3841, 4646, None), slice(51, 855, None), slice(240, 1045, None))
# box 366: 36.65 render  0.41 write
# (slice(3835, 4638, None), slice(585, 1152, None), slice(717, 1152, None))
# (slice(3842, 4646, None), slice(49, 854, None), slice(721, 1152, None))
# box 367: 36.62 render  0.34 write
# box 368: 0.24 render  0.04 write
# box 369: 0.24 render  0.04 write
# (slice(3836, 4638, None), slice(1064, 1152, None), slice(0, 559, None))
# (slice(3841, 4643, None), slice(533, 1152, None), slice(0, 564, None))
# box 370: 33.27 render  0.41 write
# (slice(3833, 4638, None), slice(1064, 1152, None), slice(237, 1038, None))
# (slice(3841, 4646, None), slice(530, 1152, None), slice(240, 1045, None))
# box 371: 34.21 render  0.63 write
# (slice(3832, 4637, None), slice(1064, 1152, None), slice(717, 1152, None))
# (slice(3842, 4646, None), slice(530, 1152, None), slice(722, 1152, None))
# box 372: 33.25 render  0.29 write
# box 373: 0.24 render  0.04 write
# box 374: 0.24 render  0.04 write
# (slice(3841, 4643, None), slice(1012, 1152, None), slice(0, 564, None))
# box 375: 16.08 render  0.18 write
# (slice(3841, 4644, None), slice(1011, 1152, None), slice(242, 1044, None))
# box 376: 15.76 render  0.13 write
# (slice(3841, 4644, None), slice(1011, 1152, None), slice(723, 1152, None))
# box 377: 17.79 render  0.18 write
# box 378: 0.24 render  0.04 write
# box 379: 0.24 render  0.09 write
# box 380: 0.24 render  0.05 write
# box 381: 0.24 render  0.04 write
# box 382: 0.24 render  0.04 write
# box 383: 0.24 render  0.06 write
# box 384: 0.24 render  0.05 write
# box 385: 0.24 render  0.04 write
# box 386: 0.24 render  0.04 write
# box 387: 0.24 render  0.05 write
# box 388: 0.24 render  0.05 write
# box 389: 0.24 render  0.04 write
# box 390: 0.24 render  0.07 write
# box 391: 0.24 render  0.05 write
# box 392: 0.24 render  0.05 write
# box 393: 0.24 render  0.04 write
# box 394: 0.24 render  0.05 write
# box 395: 0.24 render  0.04 write
# box 396: 0.24 render  0.04 write
# box 397: 0.24 render  0.04 write
# box 398: 0.31 render  0.04 write
# box 399: 0.24 render  0.04 write
# box 400: 0.24 render  0.13 write
# box 401: 0.24 render  0.14 write
# box 402: 0.24 render  0.12 write
# box 403: 0.24 render  0.13 write
# box 404: 0.24 render  0.14 write
# (slice(4316, 5118, None), slice(184, 906, None), slice(0, 559, None))
# (slice(4321, 5123, None), slice(0, 296, None), slice(0, 562, None))
# box 405: 37.13 render  0.37 write
# (slice(4316, 5118, None), slice(184, 906, None), slice(238, 1039, None))
# (slice(4321, 5126, None), slice(0, 296, None), slice(240, 1045, None))
# box 406: 37.33 render  0.59 write
# (slice(4316, 5118, None), slice(185, 907, None), slice(718, 1152, None))
# (slice(4322, 5126, None), slice(0, 294, None), slice(720, 1152, None))
# box 407: 33.59 render  0.37 write
# box 408: 0.24 render  0.07 write
# box 409: 0.24 render  0.04 write
# (slice(4316, 5118, None), slice(584, 1152, None), slice(0, 559, None))
# (slice(4321, 5123, None), slice(54, 856, None), slice(0, 563, None))
# box 410: 36.52 render  0.45 write
# (slice(4315, 5118, None), slice(584, 1152, None), slice(237, 1039, None))
# (slice(4321, 5126, None), slice(51, 855, None), slice(240, 1045, None))
# box 411: 37.51 render  0.47 write
# (slice(4315, 5118, None), slice(585, 1152, None), slice(717, 1152, None))
# (slice(4322, 5126, None), slice(50, 854, None), slice(721, 1152, None))
# box 412: 34.41 render  0.32 write
# box 413: 0.24 render  0.04 write
# box 414: 0.24 render  0.04 write
# (slice(4316, 5119, None), slice(1064, 1152, None), slice(0, 559, None))
# (slice(4321, 5123, None), slice(533, 1152, None), slice(0, 564, None))
# box 415: 33.05 render  0.74 write
# (slice(4313, 5119, None), slice(1064, 1152, None), slice(237, 1039, None))
# (slice(4321, 5126, None), slice(531, 1152, None), slice(241, 1045, None))
# box 416: 33.88 render  0.43 write
# (slice(4313, 5118, None), slice(1065, 1152, None), slice(717, 1152, None))
# (slice(4322, 5126, None), slice(531, 1152, None), slice(722, 1152, None))
# box 417: 31.58 render  0.29 write
# box 418: 0.24 render  0.04 write
# box 419: 0.24 render  0.04 write
# (slice(4321, 5123, None), slice(1012, 1152, None), slice(0, 564, None))
# box 420: 15.71 render  0.18 write
# (slice(4321, 5124, None), slice(1011, 1152, None), slice(242, 1044, None))
# box 421: 16.72 render  0.13 write
# (slice(4321, 5124, None), slice(1011, 1152, None), slice(723, 1152, None))
# box 422: 15.69 render  0.18 write
# box 423: 0.24 render  0.04 write
# box 424: 0.24 render  0.04 write
# box 425: 0.24 render  0.04 write
# box 426: 0.24 render  0.04 write
# box 427: 0.24 render  0.04 write
# box 428: 0.24 render  0.05 write
# box 429: 0.24 render  0.04 write
# box 430: 0.24 render  0.04 write
# box 431: 0.24 render  0.05 write
# box 432: 0.24 render  0.04 write
# box 433: 0.24 render  0.04 write
# box 434: 0.24 render  0.04 write
# box 435: 0.24 render  0.05 write
# box 436: 0.24 render  0.04 write
# box 437: 0.25 render  0.04 write
# box 438: 0.24 render  0.04 write
# box 439: 0.24 render  0.04 write
# box 440: 0.24 render  0.04 write
# box 441: 0.24 render  0.04 write
# box 442: 0.24 render  0.04 write
# box 443: 0.24 render  0.04 write
# box 444: 0.24 render  0.04 write
# box 445: 0.24 render  0.11 write
# box 446: 0.24 render  0.10 write
# box 447: 0.24 render  0.11 write
# box 448: 0.24 render  0.13 write
# box 449: 0.24 render  0.14 write
# (slice(4877, 5678, None), slice(185, 906, None), slice(0, 559, None))
# (slice(4881, 5683, None), slice(0, 297, None), slice(0, 562, None))
# box 450: 36.52 render  0.41 write
# (slice(4876, 5678, None), slice(185, 906, None), slice(238, 1039, None))
# (slice(4881, 5686, None), slice(0, 296, None), slice(240, 1045, None))
# box 451: 36.71 render  0.48 write
# (slice(4876, 5678, None), slice(185, 907, None), slice(718, 1152, None))
# (slice(4882, 5686, None), slice(0, 295, None), slice(720, 1152, None))
# box 452: 35.61 render  0.50 write
# box 453: 0.24 render  0.06 write
# box 454: 0.24 render  0.05 write
# (slice(4877, 5679, None), slice(585, 1152, None), slice(0, 559, None))
# (slice(4881, 5683, None), slice(55, 856, None), slice(0, 564, None))
# box 455: 35.76 render  0.55 write
# (slice(4876, 5679, None), slice(585, 1152, None), slice(238, 1039, None))
# (slice(4881, 5686, None), slice(51, 855, None), slice(240, 1045, None))
# box 456: 38.01 render  0.70 write
# (slice(4875, 5678, None), slice(585, 1152, None), slice(717, 1152, None))
# (slice(4882, 5686, None), slice(50, 855, None), slice(721, 1152, None))
# box 457: 33.83 render  0.25 write
# box 458: 0.25 render  0.06 write
# box 459: 0.25 render  0.04 write
# (slice(4877, 5679, None), slice(1065, 1152, None), slice(0, 559, None))
# (slice(4881, 5683, None), slice(533, 1152, None), slice(0, 564, None))
# box 460: 34.03 render  0.35 write
# (slice(4873, 5679, None), slice(1065, 1152, None), slice(238, 1039, None))
# (slice(4881, 5686, None), slice(531, 1152, None), slice(241, 1045, None))
# box 461: 32.92 render  0.40 write
# (slice(4873, 5678, None), slice(1065, 1152, None), slice(717, 1152, None))
# (slice(4882, 5686, None), slice(531, 1152, None), slice(722, 1152, None))
# box 462: 33.82 render  0.27 write
# box 463: 0.24 render  0.05 write
# box 464: 0.24 render  0.05 write
# (slice(4881, 5683, None), slice(1012, 1152, None), slice(0, 564, None))
# box 465: 15.86 render  0.17 write
# (slice(4881, 5684, None), slice(1012, 1152, None), slice(242, 1044, None))
# box 466: 15.91 render  0.13 write
# (slice(4881, 5684, None), slice(1012, 1152, None), slice(723, 1152, None))
# box 467: 15.53 render  0.17 write
# box 468: 0.24 render  0.04 write
# box 469: 0.24 render  0.04 write
# box 470: 0.24 render  0.04 write
# box 471: 0.24 render  0.04 write
# box 472: 0.24 render  0.04 write
# box 473: 0.24 render  0.06 write
# box 474: 0.24 render  0.04 write
# box 475: 0.24 render  0.04 write
# box 476: 0.24 render  0.04 write
# box 477: 0.24 render  0.04 write
# box 478: 0.24 render  0.04 write
# box 479: 0.24 render  0.07 write
# box 480: 0.24 render  0.04 write
# box 481: 0.24 render  0.04 write
# box 482: 0.24 render  0.04 write
# box 483: 0.28 render  0.05 write
# box 484: 0.25 render  0.05 write
# box 485: 0.24 render  0.04 write
# box 486: 0.24 render  0.04 write
# box 487: 0.24 render  0.05 write
# box 488: 0.24 render  0.04 write
# box 489: 0.24 render  0.05 write
# box 490: 0.24 render  0.13 write
# box 491: 0.24 render  0.12 write
# box 492: 0.24 render  0.12 write
# box 493: 0.24 render  0.15 write
# box 494: 0.24 render  0.11 write
# (slice(5357, 6158, None), slice(185, 906, None), slice(0, 559, None))
# (slice(5361, 6163, None), slice(0, 297, None), slice(0, 562, None))
# box 495: 36.32 render  0.39 write
# (slice(5357, 6158, None), slice(185, 907, None), slice(238, 1039, None))
# (slice(5361, 6166, None), slice(0, 297, None), slice(240, 1045, None))
# box 496: 37.98 render  0.43 write
# (slice(5356, 6158, None), slice(185, 907, None), slice(718, 1152, None))
# (slice(5362, 6166, None), slice(0, 295, None), slice(720, 1152, None))
# box 497: 34.45 render  0.31 write
# box 498: 0.24 render  0.05 write
# box 499: 0.24 render  0.04 write
# (slice(5357, 6159, None), slice(585, 1152, None), slice(0, 559, None))
# (slice(5361, 6163, None), slice(55, 856, None), slice(0, 564, None))
# box 500: 36.51 render  0.44 write
# (slice(5356, 6159, None), slice(585, 1152, None), slice(238, 1039, None))
# (slice(5361, 6166, None), slice(52, 856, None), slice(240, 1045, None))
# box 501: 37.31 render  0.43 write
# (slice(5356, 6158, None), slice(585, 1152, None), slice(718, 1152, None))
# (slice(5362, 6166, None), slice(51, 855, None), slice(721, 1152, None))
# box 502: 35.42 render  0.26 write
# box 503: 0.26 render  0.04 write
# box 504: 0.26 render  0.04 write
# (slice(5357, 6159, None), slice(1065, 1152, None), slice(0, 559, None))
# (slice(5361, 6163, None), slice(534, 1152, None), slice(0, 564, None))
# box 505: 32.63 render  0.38 write
# (slice(5353, 6159, None), slice(1065, 1152, None), slice(238, 1039, None))
# (slice(5361, 6166, None), slice(532, 1152, None), slice(241, 1045, None))
# box 506: 34.39 render  0.39 write
# (slice(5353, 6158, None), slice(1065, 1152, None), slice(717, 1152, None))
# (slice(5362, 6166, None), slice(531, 1152, None), slice(722, 1152, None))
# box 507: 31.98 render  0.25 write
# box 508: 0.25 render  0.05 write
# box 509: 0.24 render  0.05 write
# (slice(5361, 6163, None), slice(1013, 1152, None), slice(0, 564, None))
# box 510: 15.67 render  0.18 write
# (slice(5361, 6164, None), slice(1012, 1152, None), slice(242, 1044, None))
# box 511: 16.75 render  0.13 write
# (slice(5361, 6164, None), slice(1012, 1152, None), slice(723, 1152, None))
# box 512: 16.40 render  0.18 write
# box 513: 0.24 render  0.04 write
# box 514: 0.24 render  0.04 write
# box 515: 0.24 render  0.05 write
# box 516: 0.24 render  0.04 write
# box 517: 0.24 render  0.04 write
# box 518: 0.24 render  0.05 write
# box 519: 0.24 render  0.05 write
# box 520: 0.24 render  0.05 write
# box 521: 0.24 render  0.04 write
# box 522: 0.24 render  0.04 write
# box 523: 0.24 render  0.04 write
# box 524: 0.24 render  0.04 write
# box 525: 0.24 render  0.04 write
# box 526: 0.24 render  0.04 write
# box 527: 0.24 render  0.04 write
# box 528: 0.24 render  0.05 write
# box 529: 0.24 render  0.04 write
# box 530: 0.24 render  0.05 write
# box 531: 0.24 render  0.04 write
# box 532: 0.24 render  0.04 write
# box 533: 0.24 render  0.04 write
# box 534: 0.24 render  0.04 write
# box 535: 0.24 render  0.14 write
# box 536: 0.24 render  0.11 write
# box 537: 0.24 render  0.12 write
# box 538: 0.24 render  0.11 write
# box 539: 0.24 render  0.12 write
# (slice(5837, 6639, None), slice(185, 906, None), slice(0, 559, None))
# (slice(5841, 6643, None), slice(0, 297, None), slice(0, 562, None))
# box 540: 35.06 render  0.42 write
# (slice(5837, 6639, None), slice(185, 907, None), slice(238, 1039, None))
# (slice(5841, 6646, None), slice(0, 297, None), slice(240, 1045, None))
# box 541: 37.35 render  0.37 write
# (slice(5837, 6638, None), slice(185, 907, None), slice(718, 1152, None))
# (slice(5842, 6646, None), slice(0, 295, None), slice(720, 1152, None))
# box 542: 34.89 render  0.34 write
# box 543: 0.24 render  0.05 write
# box 544: 0.24 render  0.05 write
# (slice(5837, 6639, None), slice(585, 1152, None), slice(0, 559, None))
# (slice(5841, 6643, None), slice(55, 857, None), slice(0, 564, None))
# box 545: 37.05 render  0.40 write
# (slice(5836, 6639, None), slice(585, 1152, None), slice(238, 1039, None))
# (slice(5841, 6646, None), slice(52, 856, None), slice(240, 1045, None))
# box 546: 37.72 render  0.77 write
# (slice(5836, 6638, None), slice(585, 1152, None), slice(718, 1152, None))
# (slice(5842, 6646, None), slice(51, 855, None), slice(721, 1152, None))
# box 547: 33.48 render  0.29 write
# box 548: 0.24 render  0.05 write
# box 549: 0.24 render  0.06 write
# (slice(5837, 6639, None), slice(1065, 1152, None), slice(0, 559, None))
# (slice(5841, 6643, None), slice(534, 1152, None), slice(0, 564, None))
# box 550: 33.87 render  0.83 write
# (slice(5834, 6639, None), slice(1065, 1152, None), slice(238, 1039, None))
# (slice(5841, 6646, None), slice(532, 1152, None), slice(241, 1045, None))
# box 551: 33.32 render  0.35 write
# (slice(5834, 6638, None), slice(1065, 1152, None), slice(718, 1152, None))
# (slice(5842, 6646, None), slice(532, 1152, None), slice(722, 1152, None))
# box 552: 33.21 render  0.27 write
# box 553: 0.24 render  0.05 write
# box 554: 0.24 render  0.04 write
# (slice(5841, 6643, None), slice(1013, 1152, None), slice(0, 564, None))
# box 555: 16.27 render  0.17 write
# (slice(5841, 6644, None), slice(1013, 1152, None), slice(242, 1044, None))
# box 556: 16.35 render  0.13 write
# (slice(5841, 6644, None), slice(1013, 1152, None), slice(723, 1152, None))
# box 557: 15.98 render  0.19 write
# box 558: 0.24 render  0.04 write
# box 559: 0.24 render  0.05 write
# box 560: 0.24 render  0.04 write
# box 561: 0.24 render  0.04 write
# box 562: 0.24 render  0.04 write
# box 563: 0.24 render  0.05 write
# box 564: 0.24 render  0.04 write
# box 565: 0.24 render  0.04 write
# box 566: 0.24 render  0.05 write
# box 567: 0.24 render  0.05 write
# box 568: 0.24 render  0.04 write
# box 569: 0.24 render  0.05 write
# box 570: 0.24 render  0.04 write
# box 571: 0.24 render  0.04 write
# box 572: 0.24 render  0.05 write
# box 573: 0.24 render  0.04 write
# box 574: 0.24 render  0.04 write
# box 575: 0.24 render  0.04 write
# box 576: 0.24 render  0.04 write
# box 577: 0.24 render  0.05 write
# box 578: 0.24 render  0.04 write
# box 579: 0.24 render  0.04 write
# box 580: 0.24 render  0.13 write
# box 581: 0.24 render  0.12 write
# box 582: 0.24 render  0.15 write
# box 583: 0.24 render  0.11 write
# box 584: 0.24 render  0.11 write
# (slice(6397, 7087, None), slice(185, 907, None), slice(0, 559, None))
# (slice(6401, 7087, None), slice(0, 297, None), slice(0, 562, None))
# box 585: 36.59 render  0.66 write
# (slice(6397, 7087, None), slice(185, 907, None), slice(238, 1039, None))
# (slice(6401, 7087, None), slice(0, 297, None), slice(240, 1045, None))
# box 586: 37.28 render  0.50 write
# (slice(6397, 7087, None), slice(186, 907, None), slice(718, 1152, None))
# (slice(6402, 7087, None), slice(0, 296, None), slice(720, 1152, None))
# box 587: 33.60 render  0.27 write
# box 588: 0.24 render  0.04 write
# box 589: 0.24 render  0.04 write
# (slice(6397, 7087, None), slice(585, 1152, None), slice(0, 559, None))
# (slice(6401, 7087, None), slice(56, 857, None), slice(0, 564, None))
# box 590: 35.83 render  0.38 write
# (slice(6396, 7087, None), slice(585, 1152, None), slice(238, 1039, None))
# (slice(6401, 7087, None), slice(52, 856, None), slice(240, 1045, None))
# box 591: 36.50 render  0.43 write
# (slice(6396, 7087, None), slice(586, 1152, None), slice(718, 1152, None))
# (slice(6402, 7087, None), slice(52, 856, None), slice(721, 1152, None))
# box 592: 35.19 render  0.28 write
# box 593: 0.24 render  0.07 write
# box 594: 0.24 render  0.04 write
# (slice(6397, 7087, None), slice(1065, 1152, None), slice(0, 559, None))
# (slice(6401, 7087, None), slice(534, 1152, None), slice(0, 564, None))
# box 595: 32.84 render  0.40 write
# (slice(6394, 7087, None), slice(1065, 1152, None), slice(238, 1039, None))
# (slice(6401, 7087, None), slice(532, 1152, None), slice(241, 1045, None))
# box 596: 35.52 render  0.40 write
# (slice(6394, 7087, None), slice(1065, 1152, None), slice(718, 1152, None))
# (slice(6402, 7087, None), slice(532, 1152, None), slice(723, 1152, None))
# box 597: 32.79 render  0.29 write
# box 598: 0.24 render  0.04 write
# box 599: 0.24 render  0.04 write
# (slice(6402, 7087, None), slice(1014, 1152, None), slice(0, 564, None))
# box 600: 16.50 render  0.17 write
# (slice(6402, 7087, None), slice(1013, 1152, None), slice(243, 1044, None))
# box 601: 15.94 render  0.13 write
# (slice(6401, 7087, None), slice(1013, 1152, None), slice(723, 1152, None))
# box 602: 16.54 render  0.18 write
# box 603: 0.24 render  0.05 write
# box 604: 0.25 render  0.05 write
# box 605: 0.24 render  0.05 write
# box 606: 0.24 render  0.05 write
# box 607: 0.24 render  0.05 write
# box 608: 0.24 render  0.04 write
# box 609: 0.24 render  0.05 write
# box 610: 0.28 render  0.04 write
# box 611: 0.24 render  0.05 write
# box 612: 0.24 render  0.05 write
# box 613: 0.24 render  0.05 write
# box 614: 0.24 render  0.05 write
# box 615: 0.24 render  0.05 write
# box 616: 0.24 render  0.04 write
# box 617: 0.24 render  0.04 write
# box 618: 0.24 render  0.04 write
# box 619: 0.24 render  0.04 write
# box 620: 0.24 render  0.04 write
# box 621: 0.24 render  0.04 write
# box 622: 0.24 render  0.04 write
# box 623: 0.24 render  0.06 write
# box 624: 0.24 render  0.04 write
# box 625: 0.24 render  0.14 write
# box 626: 0.24 render  0.11 write
# box 627: 0.24 render  0.11 write
# box 628: 0.24 render  0.13 write
# box 629: 0.24 render  0.12 write
# (slice(6877, 7087, None), slice(185, 907, None), slice(0, 559, None))
# (slice(6881, 7087, None), slice(0, 297, None), slice(0, 563, None))
# box 630: 31.02 render  0.21 write
# (slice(6877, 7087, None), slice(185, 907, None), slice(238, 1039, None))
# (slice(6881, 7087, None), slice(0, 297, None), slice(240, 1045, None))
# box 631: 30.13 render  0.18 write
# (slice(6877, 7087, None), slice(186, 907, None), slice(718, 1152, None))
# (slice(6882, 7087, None), slice(0, 296, None), slice(720, 1152, None))
# box 632: 30.19 render  0.52 write
# box 633: 0.24 render  0.05 write
# box 634: 0.24 render  0.04 write
# (slice(6877, 7087, None), slice(585, 1152, None), slice(0, 559, None))
# (slice(6881, 7087, None), slice(56, 857, None), slice(0, 564, None))
# box 635: 29.80 render  0.23 write
# (slice(6877, 7087, None), slice(585, 1152, None), slice(238, 1039, None))
# (slice(6881, 7087, None), slice(53, 856, None), slice(240, 1045, None))
# box 636: 32.58 render  0.23 write
# (slice(6877, 7087, None), slice(586, 1152, None), slice(718, 1152, None))
# (slice(6882, 7087, None), slice(52, 856, None), slice(721, 1152, None))
# box 637: 31.43 render  0.19 write
# box 638: 0.24 render  0.05 write
# box 639: 0.24 render  0.04 write
# (slice(6877, 7087, None), slice(1065, 1152, None), slice(0, 559, None))
# (slice(6881, 7087, None), slice(535, 1152, None), slice(0, 564, None))
# box 640: 29.77 render  0.18 write
# (slice(6875, 7087, None), slice(1065, 1152, None), slice(238, 1039, None))
# (slice(6881, 7087, None), slice(533, 1152, None), slice(241, 1045, None))
# box 641: 30.36 render  0.14 write
# (slice(6875, 7087, None), slice(1066, 1152, None), slice(718, 1152, None))
# (slice(6882, 7087, None), slice(533, 1152, None), slice(723, 1152, None))
# box 642: 29.36 render  0.18 write
# box 643: 0.24 render  0.05 write
# box 644: 0.24 render  0.04 write
# (slice(6882, 7087, None), slice(1014, 1152, None), slice(0, 564, None))
# box 645: 15.37 render  0.06 write
# (slice(6882, 7087, None), slice(1014, 1152, None), slice(243, 1044, None))
# box 646: 15.84 render  0.17 write
# (slice(6882, 7087, None), slice(1014, 1152, None), slice(723, 1152, None))
# box 647: 16.82 render  0.06 write
# box 648: 0.25 render  0.04 write
# box 649: 0.25 render  0.04 write
# box 650: 0.24 render  0.04 write
# box 651: 0.24 render  0.05 write
# box 652: 0.24 render  0.04 write
# box 653: 0.24 render  0.05 write
# box 654: 0.24 render  0.05 write
# box 655: 0.24 render  0.04 write
# box 656: 0.24 render  0.04 write
# box 657: 0.24 render  0.04 write
# box 658: 0.24 render  0.04 write
# box 659: 0.24 render  0.04 write
# box 660: 0.24 render  0.04 write
# box 661: 0.24 render  0.05 write
# box 662: 0.24 render  0.05 write
# box 663: 0.24 render  0.04 write
# box 664: 0.23 render  0.04 write
# box 665: 0.24 render  0.04 write
# box 666: 0.24 render  0.05 write
# box 667: 0.24 render  0.04 write
# box 668: 0.24 render  0.04 write
# box 669: 0.29 render  0.05 write
# box 670: 0.24 render  0.12 write
# box 671: 0.24 render  0.13 write
# box 672: 0.24 render  0.12 write
# box 673: 0.24 render  0.12 write
# box 674: 0.24 render  0.12 write
# box 675: 0.24 render  0.04 write
# box 676: 0.24 render  0.04 write
# box 677: 0.24 render  0.04 write
# box 678: 0.24 render  0.04 write
# box 679: 0.24 render  0.05 write
# box 680: 0.24 render  0.05 write
# box 681: 0.24 render  0.04 write
# box 682: 0.24 render  0.05 write
# box 683: 0.24 render  0.04 write
# box 684: 0.24 render  0.05 write
# box 685: 0.24 render  0.04 write
# box 686: 0.24 render  0.04 write
# box 687: 0.24 render  0.04 write
# box 688: 0.24 render  0.04 write
# box 689: 0.24 render  0.04 write
# box 690: 0.24 render  0.04 write
# box 691: 0.24 render  0.04 write
# box 692: 0.24 render  0.04 write
# box 693: 0.30 render  0.04 write
# box 694: 0.24 render  0.04 write
# box 695: 0.24 render  0.05 write
# box 696: 0.24 render  0.04 write
# box 697: 0.24 render  0.04 write
# box 698: 0.24 render  0.04 write
# box 699: 0.24 render  0.05 write
# box 700: 0.24 render  0.07 write
# box 701: 0.24 render  0.05 write
# box 702: 0.24 render  0.04 write
# box 703: 0.24 render  0.04 write
# box 704: 0.24 render  0.04 write
# box 705: 0.24 render  0.04 write
# box 706: 0.24 render  0.04 write
# box 707: 0.24 render  0.04 write
# box 708: 0.24 render  0.04 write
# box 709: 0.24 render  0.04 write
# box 710: 0.25 render  0.05 write
# box 711: 0.24 render  0.04 write
# box 712: 0.24 render  0.04 write
# box 713: 0.24 render  0.04 write
# box 714: 0.24 render  0.04 write
# box 715: 0.24 render  0.15 write
# box 716: 0.24 render  0.10 write
# box 717: 0.24 render  0.14 write
# box 718: 0.26 render  0.16 write
# box 719: 0.24 render  0.11 write
# box 720: 0.24 render  0.04 write
# box 721: 0.24 render  0.04 write
# box 722: 0.24 render  0.04 write
# box 723: 0.24 render  0.05 write
# box 724: 0.24 render  0.04 write
# box 725: 0.24 render  0.04 write
# box 726: 0.24 render  0.04 write
# box 727: 0.24 render  0.04 write
# box 728: 0.24 render  0.04 write
# box 729: 0.24 render  0.05 write
# box 730: 0.25 render  0.04 write
# box 731: 0.25 render  0.04 write
# box 732: 0.25 render  0.04 write
# box 733: 0.24 render  0.05 write
# box 734: 0.24 render  0.04 write
# box 735: 0.24 render  0.04 write
# box 736: 0.24 render  0.04 write
# box 737: 0.24 render  0.04 write
# box 738: 0.24 render  0.04 write
# box 739: 0.24 render  0.04 write
# box 740: 0.24 render  0.04 write
# box 741: 0.24 render  0.04 write
# box 742: 0.24 render  0.04 write
# box 743: 0.24 render  0.06 write
# box 744: 0.24 render  0.04 write
# box 745: 0.24 render  0.04 write
# ...
# box 784: 0.24 render  0.06 write
# box 785: 0.24 render  0.04 write
# box 786: 0.24 render  0.04 write
# box 787: 0.24 render  0.04 write
# box 788: 0.24 render  0.04 write
# box 789: 0.24 render  0.04 write
# box 790: 0.24 render  0.08 write
# box 791: 0.23 render  0.04 write
# box 792: 0.23 render  0.05 write
# box 793: 0.24 render  0.04 write
# box 794: 0.24 render  0.04 write
# box 795: 0.24 render  0.04 write
# box 796: 0.24 render  0.05 write
# box 797: 0.24 render  0.04 write
# box 798: 0.24 render  0.04 write
# box 799: 0.24 render  0.04 write
# box 800: 0.24 render  0.04 write
# box 801: 0.24 render  0.05 write
# box 802: 0.24 render  0.04 write
# box 803: 0.24 render  0.06 write
# box 804: 0.24 render  0.05 write
# box 805: 0.24 render  0.12 write
# box 806: 0.24 render  0.11 write
# box 807: 0.24 render  0.12 write
# box 808: 0.24 render  0.11 write
# box 809: 0.23 render  0.14 write
# box 810: 0.24 render  0.05 write
# box 811: 0.24 render  0.05 write
# box 812: 0.24 render  0.04 write
# box 813: 0.24 render  0.04 write
# box 814: 0.24 render  0.04 write
# box 815: 0.24 render  0.04 write
# box 816: 0.24 render  0.05 write
# box 817: 0.24 render  0.04 write
# box 818: 0.24 render  0.04 write
# box 819: 0.24 render  0.04 write
# box 820: 0.24 render  0.04 write
# box 821: 0.24 render  0.04 write
# box 822: 0.24 render  0.04 write
# box 823: 0.23 render  0.04 write
# box 824: 0.24 render  0.04 write
# box 825: 0.24 render  0.05 write
# box 826: 0.24 render  0.04 write
# box 827: 0.24 render  0.04 write
# box 828: 0.24 render  0.04 write
# box 829: 0.24 render  0.09 write
# box 830: 0.24 render  0.04 write
# box 831: 0.24 render  0.04 write
# box 832: 0.24 render  0.04 write
# box 833: 0.24 render  0.04 write
# box 834: 0.24 render  0.05 write
# box 835: 0.24 render  0.05 write
# box 836: 0.24 render  0.05 write
# box 837: 0.25 render  0.04 write
# box 838: 0.24 render  0.05 write
# box 839: 0.24 render  0.04 write
# box 840: 0.24 render  0.04 write
# box 841: 0.24 render  0.04 write
# box 842: 0.24 render  0.05 write
# box 843: 0.24 render  0.05 write
# box 844: 0.24 render  0.04 write
# box 845: 0.24 render  0.04 write
# box 846: 0.24 render  0.04 write
# box 847: 0.24 render  0.04 write
# box 848: 0.24 render  0.06 write
# box 849: 0.24 render  0.04 write
# box 850: 0.24 render  0.12 write
# box 851: 0.24 render  0.11 write
# box 852: 0.24 render  0.16 write
# box 853: 0.24 render  0.14 write
# box 854: 0.24 render  0.11 write
# box 855: 0.24 render  0.04 write
# box 856: 0.24 render  0.04 write
# box 857: 0.24 render  0.04 write
# box 858: 0.24 render  0.04 write
# box 859: 0.24 render  0.04 write
# box 860: 0.24 render  0.04 write
# box 861: 0.24 render  0.04 write
# box 862: 0.24 render  0.04 write
# box 863: 0.24 render  0.04 write
# box 864: 0.24 render  0.04 write
# box 865: 0.24 render  0.04 write
# box 866: 0.24 render  0.05 write
# box 867: 0.25 render  0.05 write
# box 868: 0.24 render  0.07 write
# box 869: 0.24 render  0.04 write
# box 870: 0.24 render  0.04 write
# box 871: 0.24 render  0.04 write
# box 872: 0.24 render  0.04 write
# box 873: 0.24 render  0.04 write
# box 874: 0.24 render  0.04 write
# box 875: 0.24 render  0.04 write
# box 876: 0.24 render  0.09 write
# box 877: 0.24 render  0.04 write
# box 878: 0.24 render  0.04 write
# box 879: 0.24 render  0.04 write
# box 880: 0.24 render  0.04 write
# box 881: 0.24 render  0.04 write
# box 882: 0.24 render  0.04 write
# box 883: 0.24 render  0.04 write
# box 884: 0.24 render  0.04 write
# box 885: 0.24 render  0.04 write
# box 886: 0.24 render  0.04 write
# box 887: 0.24 render  0.04 write
# box 888: 0.24 render  0.04 write
# box 889: 0.24 render  0.04 write
# box 890: 0.24 render  0.05 write
# box 891: 0.24 render  0.04 write
# box 892: 0.24 render  0.04 write
# box 893: 0.24 render  0.04 write
# box 894: 0.24 render  0.04 write
# box 895: 0.24 render  0.12 write
# box 896: 0.24 render  0.11 write
# box 897: 0.24 render  0.11 write
# box 898: 0.24 render  0.11 write
# box 899: 0.24 render  0.13 write
# box 900: 0.24 render  0.05 write
# box 901: 0.24 render  0.05 write
# box 902: 0.24 render  0.04 write
# box 903: 0.24 render  0.05 write
# box 904: 0.24 render  0.04 write
# box 905: 0.24 render  0.04 write
# box 906: 0.24 render  0.04 write
# box 907: 0.24 render  0.04 write
# box 908: 0.24 render  0.04 write
# box 909: 0.24 render  0.05 write
# box 910: 0.24 render  0.04 write
# box 911: 0.24 render  0.04 write
# box 912: 0.24 render  0.04 write
# box 913: 0.24 render  0.04 write
# box 914: 0.24 render  0.05 write
# box 915: 0.24 render  0.04 write
# box 916: 0.24 render  0.04 write
# box 917: 0.24 render  0.04 write
# box 918: 0.24 render  0.06 write
# box 919: 0.30 render  0.05 write
# box 920: 0.24 render  0.04 write
# box 921: 0.24 render  0.04 write
# box 922: 0.24 render  0.04 write
# box 923: 0.24 render  0.04 write
# box 924: 0.24 render  0.06 write
# box 925: 0.24 render  0.04 write
# box 926: 0.24 render  0.05 write
# box 927: 0.24 render  0.05 write
# box 928: 0.24 render  0.05 write
# box 929: 0.24 render  0.04 write
# box 930: 0.24 render  0.04 write
# box 931: 0.24 render  0.04 write
# box 932: 0.25 render  0.04 write
# box 933: 0.24 render  0.04 write
# box 934: 0.24 render  0.05 write
# box 935: 0.24 render  0.04 write
# box 936: 0.24 render  0.04 write
# box 937: 0.24 render  0.04 write
# box 938: 0.24 render  0.04 write
# box 939: 0.24 render  0.04 write
# box 940: 0.24 render  0.20 write
# box 941: 0.23 render  0.11 write
# box 942: 0.24 render  0.10 write
# box 943: 0.24 render  0.12 write
# box 944: 0.24 render  0.15 write
# box 945: 0.24 render  0.05 write
# box 946: 0.24 render  0.05 write
# box 947: 0.24 render  0.05 write
# box 948: 0.24 render  0.10 write
# box 949: 0.24 render  0.04 write
# box 950: 0.24 render  0.04 write
# box 951: 0.24 render  0.05 write
# box 952: 0.24 render  0.04 write
# box 953: 0.24 render  0.04 write
# box 954: 0.24 render  0.04 write
# box 955: 0.24 render  0.04 write
# box 956: 0.24 render  0.06 write
# box 957: 0.24 render  0.06 write
# box 958: 0.24 render  0.04 write
# box 959: 0.24 render  0.04 write
# box 960: 0.24 render  0.04 write
# box 961: 0.24 render  0.04 write
# box 962: 0.24 render  0.04 write
# box 963: 0.24 render  0.04 write
# box 964: 0.24 render  0.04 write
# box 965: 0.24 render  0.04 write
# box 966: 0.24 render  0.04 write
# box 967: 0.24 render  0.04 write
# box 968: 0.24 render  0.04 write
# box 969: 0.24 render  0.04 write
# box 970: 0.24 render  0.04 write
# box 971: 0.24 render  0.04 write
# box 972: 0.24 render  0.04 write
# box 973: 0.24 render  0.04 write
# box 974: 0.24 render  0.04 write
# box 975: 0.24 render  0.04 write
# box 976: 0.24 render  0.04 write
# box 977: 0.24 render  0.04 write
# box 978: 0.24 render  0.04 write
# box 979: 0.24 render  0.04 write
# box 980: 0.24 render  0.04 write
# box 981: 0.24 render  0.04 write
# box 982: 0.24 render  0.04 write
# box 983: 0.24 render  0.04 write
# box 984: 0.24 render  0.04 write
# box 985: 0.24 render  0.11 write
# box 986: 0.24 render  0.12 write
# box 987: 0.24 render  0.11 write
# box 988: 0.24 render  0.10 write
# box 989: 0.24 render  0.10 write
# box 990: 0.24 render  0.04 write
# box 991: 0.24 render  0.04 write
# box 992: 0.24 render  0.04 write
# box 993: 0.24 render  0.04 write
# box 994: 0.24 render  0.05 write
# box 995: 0.24 render  0.04 write
# box 996: 0.24 render  0.04 write
# box 997: 0.24 render  0.04 write
# box 998: 0.24 render  0.04 write
# box 999: 0.24 render  0.04 write
# box 1000: 0.24 render  0.04 write
# box 1001: 0.24 render  0.04 write
# box 1002: 0.24 render  0.04 write
# box 1003: 0.24 render  0.04 write
# box 1004: 0.24 render  0.04 write
# box 1005: 0.24 render  0.04 write
# box 1006: 0.24 render  0.05 write
# box 1007: 0.24 render  0.04 write
# box 1008: 0.24 render  0.04 write
# box 1009: 0.24 render  0.04 write
# box 1010: 0.24 render  0.04 write
# box 1011: 0.24 render  0.05 write
# box 1012: 0.24 render  0.04 write
# box 1013: 0.24 render  0.04 write
# box 1014: 0.24 render  0.04 write
# box 1015: 0.24 render  0.04 write
# box 1016: 0.24 render  0.04 write
# box 1017: 0.24 render  0.04 write
# box 1018: 0.24 render  0.04 write
# box 1019: 0.24 render  0.04 write
# box 1020: 0.24 render  0.04 write
# box 1021: 0.24 render  0.04 write
# box 1022: 0.23 render  0.11 write
# box 1023: 0.24 render  0.04 write
# box 1024: 0.24 render  0.04 write
# box 1025: 0.24 render  0.04 write
# box 1026: 0.24 render  0.04 write
# box 1027: 0.24 render  0.04 write
# box 1028: 0.24 render  0.04 write
# box 1029: 0.24 render  0.04 write
# box 1030: 0.23 render  0.11 write
# box 1031: 0.24 render  0.13 write
# box 1032: 0.24 render  0.11 write
# box 1033: 0.24 render  0.12 write
# box 1034: 0.24 render  0.10 write
# box 1035: 0.24 render  0.04 write
# box 1036: 0.24 render  0.04 write
# box 1037: 0.24 render  0.04 write
# box 1038: 0.24 render  0.04 write
# box 1039: 0.24 render  0.09 write
# box 1040: 0.24 render  0.05 write
# box 1041: 0.24 render  0.04 write
# box 1042: 0.24 render  0.04 write
# box 1043: 0.24 render  0.05 write
# box 1044: 0.24 render  0.06 write
# box 1045: 0.24 render  0.04 write
# box 1046: 0.25 render  0.04 write
# box 1047: 0.25 render  0.04 write
# box 1048: 0.25 render  0.04 write
# box 1049: 0.25 render  0.04 write
# box 1050: 0.25 render  0.04 write
# box 1051: 0.25 render  0.04 write
# box 1052: 0.25 render  0.04 write
# box 1053: 0.24 render  0.04 write
# box 1054: 0.24 render  0.04 write
# box 1055: 0.24 render  0.05 write
# box 1056: 0.24 render  0.04 write
# box 1057: 0.24 render  0.04 write
# box 1058: 0.24 render  0.04 write
# box 1059: 0.24 render  0.04 write
# box 1060: 0.24 render  0.04 write
# box 1061: 0.24 render  0.04 write
# box 1062: 0.24 render  0.04 write
# box 1063: 0.24 render  0.04 write
# box 1064: 0.24 render  0.04 write
# box 1065: 0.24 render  0.04 write
# box 1066: 0.24 render  0.04 write
# box 1067: 0.24 render  0.04 write
# box 1068: 0.24 render  0.04 write
# box 1069: 0.24 render  0.04 write
# box 1070: 0.24 render  0.06 write
# box 1071: 0.24 render  0.04 write
# box 1072: 0.24 render  0.04 write
# box 1073: 0.24 render  0.05 write
# box 1074: 0.24 render  0.04 write
# box 1075: 0.24 render  0.24 write
# box 1076: 0.24 render  0.11 write
# box 1077: 0.24 render  0.11 write
# box 1078: 0.24 render  0.12 write
# box 1079: 0.24 render  0.11 write
# box 1080: 0.24 render  0.04 write
# box 1081: 0.24 render  0.04 write
# box 1082: 0.24 render  0.04 write
# box 1083: 0.24 render  0.04 write
# box 1084: 0.24 render  0.04 write
# box 1085: 0.24 render  0.04 write
# box 1086: 0.24 render  0.04 write
# box 1087: 0.24 render  0.04 write
# box 1088: 0.24 render  0.05 write
# box 1089: 0.24 render  0.04 write
# box 1090: 0.24 render  0.04 write
# box 1091: 0.24 render  0.04 write
# box 1092: 0.24 render  0.04 write
# box 1093: 0.24 render  0.04 write
# box 1094: 0.24 render  0.04 write
# box 1095: 0.24 render  0.04 write
# box 1096: 0.24 render  0.04 write
# box 1097: 0.24 render  0.04 write
# box 1098: 0.24 render  0.04 write
# box 1099: 0.24 render  0.04 write
# box 1100: 0.24 render  0.08 write
# box 1101: 0.24 render  0.04 write
# box 1102: 0.24 render  0.04 write
# box 1103: 0.24 render  0.04 write
# box 1104: 0.25 render  0.04 write
# box 1105: 0.24 render  0.04 write
# box 1106: 0.24 render  0.05 write
# box 1107: 0.24 render  0.04 write
# box 1108: 0.24 render  0.06 write
# box 1109: 0.24 render  0.04 write
# box 1110: 0.24 render  0.04 write
# box 1111: 0.24 render  0.04 write
# box 1112: 0.24 render  0.04 write
# box 1113: 0.24 render  0.04 write
# box 1114: 0.24 render  0.04 write
# box 1115: 0.24 render  0.04 write
# box 1116: 0.24 render  0.04 write
# box 1117: 0.24 render  0.05 write
# box 1118: 0.24 render  0.04 write
# box 1119: 0.24 render  0.04 write
# box 1120: 0.24 render  0.14 write
# box 1121: 0.24 render  0.11 write
# box 1122: 0.24 render  0.11 write
# box 1123: 0.30 render  0.10 write
# box 1124: 0.24 render  0.11 write
# box 1125: 0.24 render  0.05 write
# box 1126: 0.24 render  0.04 write
# box 1127: 0.24 render  0.04 write
# box 1128: 0.24 render  0.04 write
# box 1129: 0.24 render  0.04 write
# box 1130: 0.24 render  0.04 write
# box 1131: 0.24 render  0.04 write
# box 1132: 0.24 render  0.04 write
# box 1133: 0.24 render  0.04 write
# box 1134: 0.23 render  0.04 write
# box 1135: 0.24 render  0.04 write
# box 1136: 0.24 render  0.04 write
# box 1137: 0.24 render  0.04 write
# box 1138: 0.24 render  0.04 write
# box 1139: 0.24 render  0.04 write
# box 1140: 0.24 render  0.04 write
# box 1141: 0.24 render  0.04 write
# box 1142: 0.24 render  0.05 write
# box 1143: 0.24 render  0.04 write
# box 1144: 0.24 render  0.05 write
# box 1145: 0.24 render  0.04 write
# box 1146: 0.24 render  0.04 write
# box 1147: 0.24 render  0.04 write
# box 1148: 0.24 render  0.04 write
# box 1149: 0.24 render  0.06 write
# box 1150: 0.24 render  0.04 write
# box 1151: 0.24 render  0.04 write
# box 1152: 0.24 render  0.04 write
# box 1153: 0.24 render  0.04 write
# box 1154: 0.24 render  0.04 write
# box 1155: 0.24 render  0.05 write
# box 1156: 0.24 render  0.07 write
# box 1157: 0.24 render  0.04 write
# box 1158: 0.24 render  0.04 write
# box 1159: 0.24 render  0.04 write
# box 1160: 0.24 render  0.04 write
# box 1161: 0.24 render  0.05 write
# box 1162: 0.24 render  0.04 write
# box 1163: 0.24 render  0.04 write
# box 1164: 0.24 render  0.04 write
# box 1165: 0.24 render  0.15 write
# box 1166: 0.24 render  0.10 write
# box 1167: 0.24 render  0.10 write
# box 1168: 0.24 render  0.12 write
# box 1169: 0.24 render  0.11 write
# box 1170: 0.24 render  0.04 write
# box 1171: 0.25 render  0.04 write
# box 1172: 0.24 render  0.04 write
# box 1173: 0.24 render  0.06 write
# box 1174: 0.24 render  0.04 write
# box 1175: 0.24 render  0.05 write
# box 1176: 0.24 render  0.04 write
# box 1177: 0.24 render  0.04 write
# box 1178: 0.24 render  0.04 write
# box 1179: 0.24 render  0.04 write
# box 1180: 0.24 render  0.04 write
# box 1181: 0.24 render  0.04 write
# box 1182: 0.24 render  0.04 write
# box 1183: 0.24 render  0.05 write
# box 1184: 0.24 render  0.04 write
# box 1185: 0.24 render  0.04 write
# box 1186: 0.24 render  0.04 write
# box 1187: 0.24 render  0.04 write
# box 1188: 0.24 render  0.04 write
# box 1189: 0.24 render  0.04 write
# box 1190: 0.24 render  0.04 write
# box 1191: 0.24 render  0.04 write
# box 1192: 0.24 render  0.04 write
# box 1193: 0.24 render  0.04 write
# box 1194: 0.24 render  0.04 write
# box 1195: 0.24 render  0.04 write
# box 1196: 0.24 render  0.04 write
# box 1197: 0.24 render  0.08 write
# box 1198: 0.24 render  0.04 write
# box 1199: 0.24 render  0.04 write
# box 1200: 0.24 render  0.04 write
# box 1201: 0.23 render  0.04 write
# box 1202: 0.24 render  0.04 write
# box 1203: 0.24 render  0.04 write
# box 1204: 0.24 render  0.05 write
# box 1205: 0.24 render  0.04 write
# box 1206: 0.24 render  0.04 write
# box 1207: 0.24 render  0.04 write
# box 1208: 0.24 render  0.04 write
# box 1209: 0.24 render  0.04 write
# box 1210: 0.24 render  0.14 write
# box 1211: 0.24 render  0.11 write
# box 1212: 0.24 render  0.10 write
# box 1213: 0.24 render  0.11 write
# box 1214: 0.24 render  0.14 write
# box 1215: 0.24 render  0.13 write
# box 1216: 0.24 render  0.08 write
# box 1217: 0.24 render  0.08 write
# box 1218: 0.24 render  0.09 write
# box 1219: 0.24 render  0.10 write
# box 1220: 0.24 render  0.10 write
# box 1221: 0.24 render  0.09 write
# box 1222: 0.24 render  0.09 write
# box 1223: 0.24 render  0.08 write
# box 1224: 0.24 render  0.09 write
# box 1225: 0.24 render  0.09 write
# box 1226: 0.25 render  0.09 write
# box 1227: 0.24 render  0.09 write
# box 1228: 0.24 render  0.10 write
# box 1229: 0.24 render  0.09 write
# box 1230: 0.24 render  0.08 write
# box 1231: 0.24 render  0.09 write
# box 1232: 0.24 render  0.09 write
# box 1233: 0.24 render  0.09 write
# box 1234: 0.24 render  0.08 write
# box 1235: 0.24 render  0.10 write
# box 1236: 0.24 render  0.08 write
# box 1237: 0.24 render  0.11 write
# box 1238: 0.24 render  0.08 write
# box 1239: 0.24 render  0.09 write
# box 1240: 0.24 render  0.10 write
# box 1241: 0.24 render  0.08 write
# box 1242: 0.25 render  0.09 write
# box 1243: 0.24 render  0.09 write
# box 1244: 0.24 render  0.07 write
# box 1245: 0.24 render  0.11 write
# box 1246: 0.24 render  0.08 write
# box 1247: 0.24 render  0.09 write
# box 1248: 0.24 render  0.11 write
# box 1249: 0.24 render  0.08 write
# box 1250: 0.24 render  0.08 write
# box 1251: 0.24 render  0.09 write
# box 1252: 0.24 render  0.09 write
# box 1253: 0.24 render  0.09 write
# box 1254: 0.24 render  0.09 write
# box 1255: 0.24 render  0.15 write
# box 1256: 0.24 render  0.13 write
# box 1257: 0.24 render  0.12 write
# box 1258: 0.24 render  0.16 write
# box 1259: 0.24 render  0.12 write

# %%
from connectomics.common import file

cloud_storage = CloudStorage.S3
bucket = 'aind-open-data'
dataset_path = 'diSPIM_647459_2022-12-07_00-00-00/diSPIM.zarr'
downsample_exp = 2
tile_names = ['tile_X_0000_Y_0000_Z_0000_CH_0405_cam1.zarr', 
                'tile_X_0001_Y_0000_Z_0000_CH_0405_cam1.zarr']
tile_layout = np.array([[1],
                        [0]])
input_zarr = ZarrDataset(cloud_storage=cloud_storage,
                            bucket=bucket,
                            dataset_path=dataset_path, 
                            tile_names=tile_names,
                            downsample_exp=downsample_exp)

# Application Outputs
output_cloud_storage = CloudStorage.GCS
output_bucket = 'sofima-test-bucket'
output_path = 'output_level_0_debug.zarr'   # This is your output name!


data_path = 'fine_mesh_data.npz'
with file.Open(data_path, 'rb') as f:
    data = np.load(f, allow_pickle=True)
fine_mesh = data['fine_mesh']
fine_mesh_xy_to_index = data['fine_mesh_xy_to_index'].item()
stride_zyx = tuple(data['stride_zyx'])

zarr_stitcher = ZarrStitcher(input_zarr, tile_layout)
cx, cy, coarse_mesh = zarr_stitcher.run_coarse_registration()
zarr_stitcher._run_fusion(output_cloud_storage=output_cloud_storage,
                        output_bucket=output_bucket,
                        output_path=output_path,
                        downsample_exp=0,
                        cx=cx,
                        cy=cy,
                        fine_mesh=fine_mesh,
                        fine_mesh_xy_to_index=fine_mesh_xy_to_index,
                        stride_zyx=stride_zyx)
# Out:
# Top Id: 1, Bottom Id: 0
# Top: (0, 0), Bot: (1, 0) [ -1. 285.  -4.]
# scale_factor=4
# tg_box=BoundingBox(start=(0, 7, 0), size=(29, 29, 178), is_border_start=(False, False, False), is_border_end=(False, False, False))
# out_box=BoundingBox(start=(0, 560, 0), size=(2320, 2320, 14240), is_border_start=(False, False, False), is_border_end=(False, False, False))
# tg_box=BoundingBox(start=(-1, -8, -1), size=(30, 29, 178), is_border_start=(False, False, False), is_border_end=(False, False, False))
# out_box=BoundingBox(start=(-80, 1664, -80), size=(2400, 2320, 14240), is_border_start=(False, False, False), is_border_end=(False, False, False))
# crop_offset=MutableArray([  80., -560.,   80.])
# fused_shape_5d=[1, 1, 14172, 3468, 2304]
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1687410616.326251    7849 gcs_resource.cc:102] Using default AdmissionQueue with limit 32
# I0000 00:00:1687410616.335055    8511 google_auth_provider.cc:179] Running on GCE, using service account 895865026362-compute@developer.gserviceaccount.com
# (slice(0, 551, None), slice(0, 604, None), slice(0, 558, None))
# box 0: 29.83 render  0.45 write
# (slice(0, 552, None), slice(0, 606, None), slice(235, 1038, None))
# box 1: 21.99 render  0.33 write
# (slice(0, 553, None), slice(0, 607, None), slice(715, 1518, None))
# box 2: 19.54 render  0.43 write
# (slice(0, 554, None), slice(0, 608, None), slice(1275, 2078, None))
# box 3: 19.56 render  0.88 write
# (slice(0, 554, None), slice(0, 608, None), slice(1515, 2304, None))
# box 4: 19.92 render  0.41 write
# (slice(0, 551, None), slice(281, 1083, None), slice(0, 557, None))
# box 5: 20.89 render  0.46 write
# (slice(0, 551, None), slice(281, 1087, None), slice(233, 1038, None))
# box 6: 20.98 render  0.51 write
# (slice(0, 552, None), slice(283, 1088, None), slice(713, 1518, None))
# box 7: 19.98 render  0.46 write
# (slice(0, 554, None), slice(285, 1088, None), slice(1272, 2078, None))
# box 8: 20.21 render  0.40 write
# (slice(0, 554, None), slice(285, 1088, None), slice(1514, 2304, None))
# box 9: 19.93 render  0.32 write
# (slice(0, 551, None), slice(761, 1565, None), slice(0, 555, None))
# (slice(0, 572, None), slice(0, 499, None), slice(0, 570, None))
# box 10: 44.39 render  0.38 write
# (slice(0, 551, None), slice(761, 1570, None), slice(231, 1037, None))
# (slice(0, 576, None), slice(0, 498, None), slice(241, 1051, None))
# box 11: 38.71 render  0.37 write
# (slice(0, 553, None), slice(763, 1570, None), slice(708, 1519, None))
# (slice(0, 576, None), slice(0, 499, None), slice(723, 1529, None))
# box 12: 36.49 render  0.56 write
# (slice(0, 554, None), slice(765, 1567, None), slice(1270, 2080, None))
# (slice(0, 572, None), slice(0, 503, None), slice(1279, 2086, None))
# box 13: 38.08 render  0.37 write
# (slice(0, 554, None), slice(765, 1564, None), slice(1514, 2304, None))
# (slice(0, 566, None), slice(0, 503, None), slice(1518, 2304, None))
# box 14: 37.87 render  0.40 write
# (slice(0, 551, None), slice(1319, 2128, None), slice(0, 554, None))
# (slice(0, 573, None), slice(174, 977, None), slice(0, 570, None))
# box 15: 35.80 render  0.33 write
# (slice(0, 551, None), slice(1320, 2128, None), slice(221, 1037, None))
# (slice(0, 576, None), slice(169, 978, None), slice(241, 1051, None))
# box 16: 37.87 render  0.54 write
# (slice(0, 553, None), slice(1323, 2127, None), slice(705, 1519, None))
# (slice(0, 576, None), slice(169, 980, None), slice(723, 1526, None))
# box 17: 36.74 render  0.36 write
# (slice(0, 554, None), slice(1323, 2124, None), slice(1270, 2080, None))
# (slice(0, 572, None), slice(171, 981, None), slice(1278, 2084, None))
# box 18: 37.15 render  0.36 write
# (slice(0, 554, None), slice(1323, 2125, None), slice(1515, 2304, None))
# (slice(0, 566, None), slice(175, 981, None), slice(1517, 2304, None))
# box 19: 37.98 render  0.32 write
# (slice(0, 549, None), slice(1796, 2288, None), slice(0, 548, None))
# (slice(0, 573, None), slice(651, 1457, None), slice(0, 570, None))
# box 20: 31.33 render  0.42 write
# (slice(0, 548, None), slice(1798, 2288, None), slice(221, 1037, None))
# (slice(0, 575, None), slice(650, 1459, None), slice(243, 1048, None))
# box 21: 33.12 render  0.35 write
# (slice(0, 553, None), slice(1802, 2287, None), slice(705, 1519, None))
# (slice(0, 575, None), slice(650, 1460, None), slice(721, 1522, None))
# box 22: 32.14 render  0.37 write
# (slice(0, 553, None), slice(1802, 2284, None), slice(1275, 2079, None))
# (slice(0, 566, None), slice(655, 1460, None), slice(1278, 2082, None))
# box 23: 33.32 render  0.33 write
# (slice(0, 553, None), slice(1802, 2285, None), slice(1517, 2304, None))
# (slice(0, 563, None), slice(657, 1461, None), slice(1517, 2304, None))
# box 24: 31.62 render  0.38 write
# (slice(0, 569, None), slice(1212, 2018, None), slice(0, 566, None))
# box 25: 19.73 render  0.74 write
# (slice(0, 569, None), slice(1212, 2019, None), slice(240, 1043, None))
# box 26: 19.58 render  0.41 write
# (slice(0, 568, None), slice(1214, 2020, None), slice(719, 1522, None))
# box 27: 19.58 render  0.41 write
# (slice(0, 564, None), slice(1217, 2021, None), slice(1278, 2081, None))
# box 28: 21.16 render  0.44 write
# (slice(0, 563, None), slice(1218, 2021, None), slice(1518, 2304, None))
# box 29: 19.26 render  0.37 write
# (slice(0, 567, None), slice(1611, 2258, None), slice(0, 564, None))
# box 30: 18.18 render  0.58 write
# (slice(0, 567, None), slice(1613, 2259, None), slice(240, 1042, None))
# box 31: 20.31 render  0.51 write
# (slice(0, 566, None), slice(1615, 2260, None), slice(719, 1522, None))
# box 32: 19.04 render  0.51 write
# (slice(0, 563, None), slice(1617, 2261, None), slice(1278, 2081, None))
# box 33: 19.45 render  0.60 write
# (slice(0, 562, None), slice(1618, 2261, None), slice(1518, 2304, None))
# box 34: 19.54 render  0.49 write
# (slice(229, 1032, None), slice(0, 605, None), slice(0, 558, None))
# box 35: 19.62 render  0.58 write
# (slice(229, 1032, None), slice(0, 607, None), slice(235, 1038, None))
# box 36: 20.30 render  0.41 write
# (slice(229, 1033, None), slice(0, 608, None), slice(715, 1518, None))
# box 37: 21.31 render  0.44 write
# (slice(230, 1034, None), slice(0, 609, None), slice(1275, 2078, None))
# box 38: 20.50 render  0.50 write
# (slice(231, 1034, None), slice(0, 609, None), slice(1514, 2304, None))
# box 39: 20.94 render  0.84 write
# (slice(228, 1031, None), slice(281, 1084, None), slice(0, 557, None))
# box 40: 20.35 render  0.43 write
# (slice(227, 1031, None), slice(282, 1087, None), slice(233, 1037, None))
# box 41: 22.00 render  0.44 write
# (slice(227, 1032, None), slice(284, 1090, None), slice(713, 1518, None))
# box 42: 21.56 render  0.57 write
# (slice(230, 1033, None), slice(285, 1090, None), slice(1272, 2078, None))
# box 43: 21.59 render  0.43 write
# (slice(231, 1034, None), slice(286, 1090, None), slice(1512, 2304, None))
# box 44: 21.31 render  0.33 write
# (slice(225, 1031, None), slice(761, 1565, None), slice(0, 555, None))
# (slice(245, 1051, None), slice(0, 501, None), slice(0, 568, None))
# box 45: 37.42 render  0.55 write
# (slice(223, 1031, None), slice(761, 1571, None), slice(232, 1036, None))
# (slice(247, 1055, None), slice(0, 501, None), slice(241, 1052, None))
# box 46: 39.38 render  0.43 write
# (slice(223, 1032, None), slice(763, 1571, None), slice(708, 1518, None))
# (slice(242, 1055, None), slice(0, 500, None), slice(723, 1532, None))
# box 47: 40.03 render  0.47 write
# (slice(230, 1034, None), slice(766, 1569, None), slice(1269, 2080, None))
# (slice(238, 1052, None), slice(0, 504, None), slice(1281, 2088, None))
# box 48: 40.37 render  0.45 write
# (slice(231, 1034, None), slice(765, 1565, None), slice(1512, 2304, None))
# (slice(238, 1047, None), slice(0, 504, None), slice(1520, 2304, None))
# box 49: 39.06 render  0.37 write
# (slice(220, 1031, None), slice(1319, 2128, None), slice(0, 554, None))
# (slice(245, 1050, None), slice(175, 980, None), slice(0, 570, None))
# box 50: 37.55 render  0.47 write
# (slice(220, 1031, None), slice(1320, 2130, None), slice(223, 1036, None))
# (slice(246, 1055, None), slice(170, 979, None), slice(241, 1052, None))
# box 51: 41.85 render  0.43 write
# (slice(221, 1032, None), slice(1324, 2130, None), slice(705, 1519, None))
# (slice(242, 1055, None), slice(170, 981, None), slice(724, 1529, None))
# box 52: 38.53 render  0.45 write
# (slice(230, 1034, None), slice(1323, 2124, None), slice(1269, 2080, None))
# (slice(238, 1052, None), slice(172, 982, None), slice(1280, 2086, None))
# box 53: 40.87 render  0.45 write
# (slice(232, 1034, None), slice(1323, 2125, None), slice(1513, 2304, None))
# (slice(238, 1047, None), slice(175, 982, None), slice(1519, 2304, None))
# box 54: 38.35 render  0.42 write
# (slice(220, 1030, None), slice(1797, 2288, None), slice(0, 551, None))
# (slice(246, 1049, None), slice(652, 1458, None), slice(0, 570, None))
# box 55: 34.42 render  0.39 write
# (slice(220, 1030, None), slice(1799, 2290, None), slice(223, 1036, None))
# (slice(244, 1054, None), slice(651, 1460, None), slice(242, 1050, None))
# box 56: 33.67 render  0.46 write
# (slice(221, 1032, None), slice(1802, 2290, None), slice(705, 1519, None))
# (slice(241, 1054, None), slice(651, 1461, None), slice(722, 1524, None))
# box 57: 34.19 render  0.33 write
# (slice(230, 1033, None), slice(1802, 2284, None), slice(1274, 2079, None))
# (slice(238, 1047, None), slice(656, 1461, None), slice(1280, 2083, None))
# box 58: 33.31 render  0.43 write
# (slice(232, 1033, None), slice(1802, 2285, None), slice(1517, 2304, None))
# (slice(238, 1044, None), slice(658, 1462, None), slice(1519, 2304, None))
# box 59: 34.84 render  0.35 write
# (slice(244, 1048, None), slice(1213, 2020, None), slice(0, 567, None))
# box 60: 19.83 render  0.43 write
# (slice(242, 1048, None), slice(1213, 2020, None), slice(241, 1045, None))
# box 61: 21.40 render  0.41 write
# (slice(240, 1048, None), slice(1215, 2021, None), slice(720, 1524, None))
# box 62: 21.85 render  0.41 write
# (slice(238, 1045, None), slice(1217, 2021, None), slice(1279, 2083, None))
# box 63: 22.65 render  0.34 write
# (slice(237, 1043, None), slice(1218, 2022, None), slice(1519, 2304, None))
# box 64: 22.10 render  0.47 write
# (slice(243, 1047, None), slice(1612, 2260, None), slice(0, 565, None))
# box 65: 20.98 render  0.70 write
# (slice(242, 1046, None), slice(1614, 2260, None), slice(240, 1044, None))
# box 66: 20.68 render  0.48 write
# (slice(240, 1046, None), slice(1616, 2261, None), slice(720, 1524, None))
# box 67: 19.86 render  0.54 write
# (slice(237, 1044, None), slice(1618, 2261, None), slice(1279, 2083, None))
# box 68: 21.18 render  0.62 write
# (slice(237, 1043, None), slice(1618, 2261, None), slice(1519, 2304, None))
# box 69: 21.68 render  0.51 write
# (slice(709, 1512, None), slice(0, 606, None), slice(0, 558, None))
# box 70: 19.32 render  0.42 write
# (slice(709, 1512, None), slice(0, 608, None), slice(235, 1037, None))
# box 71: 20.34 render  0.36 write
# (slice(709, 1513, None), slice(0, 609, None), slice(715, 1517, None))
# box 72: 21.00 render  0.43 write
# (slice(710, 1514, None), slice(0, 610, None), slice(1274, 2077, None))
# box 73: 20.15 render  0.46 write
# (slice(711, 1514, None), slice(0, 610, None), slice(1514, 2304, None))
# box 74: 19.96 render  0.48 write
# (slice(709, 1512, None), slice(282, 1085, None), slice(0, 557, None))
# box 75: 20.66 render  0.42 write
# (slice(707, 1512, None), slice(282, 1089, None), slice(234, 1037, None))
# box 76: 21.27 render  0.39 write
# (slice(707, 1512, None), slice(284, 1091, None), slice(713, 1517, None))
# box 77: 20.78 render  0.45 write
# (slice(708, 1513, None), slice(286, 1091, None), slice(1272, 2078, None))
# box 78: 22.47 render  0.42 write
# (slice(710, 1513, None), slice(286, 1091, None), slice(1512, 2304, None))
# box 79: 20.90 render  0.75 write
# (slice(707, 1511, None), slice(761, 1565, None), slice(0, 555, None))
# (slice(726, 1530, None), slice(0, 503, None), slice(0, 566, None))
# box 80: 37.29 render  0.49 write
# (slice(702, 1511, None), slice(762, 1572, None), slice(234, 1035, None))
# (slice(726, 1535, None), slice(0, 503, None), slice(241, 1052, None))
# box 81: 38.52 render  0.35 write
# (slice(702, 1511, None), slice(764, 1572, None), slice(709, 1517, None))
# (slice(723, 1535, None), slice(0, 500, None), slice(723, 1532, None))
# box 82: 41.26 render  0.60 write
# (slice(706, 1514, None), slice(766, 1572, None), slice(1268, 2080, None))
# (slice(719, 1533, None), slice(0, 505, None), slice(1286, 2089, None))
# box 83: 38.69 render  0.40 write
# (slice(710, 1514, None), slice(766, 1569, None), slice(1511, 2304, None))
# (slice(718, 1528, None), slice(0, 505, None), slice(1522, 2304, None))
# box 84: 38.41 render  0.41 write
# (slice(702, 1511, None), slice(1321, 2129, None), slice(0, 555, None))
# (slice(726, 1529, None), slice(178, 983, None), slice(0, 569, None))
# box 85: 36.94 render  0.33 write
# (slice(701, 1511, None), slice(1321, 2132, None), slice(227, 1034, None))
# (slice(726, 1535, None), slice(172, 981, None), slice(241, 1052, None))
# box 86: 40.98 render  0.49 write
# (slice(701, 1511, None), slice(1324, 2132, None), slice(705, 1519, None))
# (slice(722, 1535, None), slice(171, 982, None), slice(724, 1530, None))
# box 87: 38.89 render  0.49 write
# (slice(706, 1514, None), slice(1323, 2126, None), slice(1268, 2080, None))
# (slice(719, 1533, None), slice(172, 983, None), slice(1282, 2087, None))
# box 88: 38.15 render  0.41 write
# (slice(710, 1514, None), slice(1323, 2125, None), slice(1512, 2304, None))
# (slice(718, 1527, None), slice(175, 983, None), slice(1521, 2304, None))
# box 89: 38.69 render  0.35 write
# (slice(702, 1511, None), slice(1800, 2289, None), slice(0, 552, None))
# (slice(726, 1527, None), slice(655, 1460, None), slice(0, 569, None))
# box 90: 32.19 render  0.41 write
# (slice(701, 1511, None), slice(1801, 2292, None), slice(227, 1034, None))
# (slice(724, 1534, None), slice(652, 1461, None), slice(242, 1052, None))
# box 91: 34.74 render  0.41 write
# (slice(701, 1511, None), slice(1802, 2292, None), slice(705, 1519, None))
# (slice(722, 1534, None), slice(652, 1462, None), slice(723, 1525, None))
# box 92: 33.98 render  0.48 write
# (slice(709, 1514, None), slice(1802, 2286, None), slice(1270, 2080, None))
# (slice(719, 1530, None), slice(656, 1462, None), slice(1282, 2084, None))
# box 93: 33.94 render  0.34 write
# (slice(711, 1514, None), slice(1802, 2285, None), slice(1516, 2304, None))
# (slice(718, 1525, None), slice(659, 1463, None), slice(1521, 2304, None))
# box 94: 33.00 render  0.36 write
# (slice(724, 1527, None), slice(1215, 2021, None), slice(0, 568, None))
# box 95: 21.37 render  0.42 write
# (slice(722, 1528, None), slice(1215, 2021, None), slice(242, 1047, None))
# box 96: 20.77 render  0.32 write
# (slice(721, 1528, None), slice(1216, 2021, None), slice(722, 1525, None))
# box 97: 21.03 render  0.38 write
# (slice(718, 1526, None), slice(1219, 2022, None), slice(1281, 2084, None))
# box 98: 21.44 render  0.32 write
# (slice(718, 1524, None), slice(1219, 2022, None), slice(1521, 2304, None))
# box 99: 21.23 render  0.38 write
# (slice(723, 1526, None), slice(1615, 2261, None), slice(0, 567, None))
# box 100: 19.25 render  0.54 write
# (slice(722, 1526, None), slice(1616, 2261, None), slice(242, 1046, None))
# box 101: 20.45 render  0.53 write
# (slice(720, 1526, None), slice(1618, 2261, None), slice(721, 1525, None))
# box 102: 20.81 render  0.57 write
# (slice(718, 1524, None), slice(1619, 2262, None), slice(1281, 2084, None))
# box 103: 21.74 render  0.57 write
# (slice(718, 1523, None), slice(1619, 2262, None), slice(1521, 2304, None))
# box 104: 20.47 render  0.70 write
# (slice(1270, 2073, None), slice(0, 607, None), slice(0, 557, None))
# box 105: 20.02 render  0.30 write
# (slice(1270, 2073, None), slice(0, 609, None), slice(235, 1037, None))
# box 106: 21.34 render  0.40 write
# (slice(1270, 2073, None), slice(0, 610, None), slice(715, 1517, None))
# box 107: 20.10 render  0.39 write
# (slice(1270, 2073, None), slice(0, 611, None), slice(1274, 2076, None))
# box 108: 20.71 render  0.41 write
# (slice(1270, 2073, None), slice(0, 612, None), slice(1514, 2304, None))
# box 109: 21.01 render  0.41 write
# (slice(1269, 2073, None), slice(283, 1086, None), slice(0, 557, None))
# box 110: 20.33 render  0.38 write
# (slice(1267, 2073, None), slice(283, 1089, None), slice(234, 1036, None))
# box 111: 21.04 render  0.35 write
# (slice(1267, 2072, None), slice(285, 1092, None), slice(713, 1516, None))
# box 112: 22.10 render  0.58 write
# (slice(1267, 2073, None), slice(287, 1092, None), slice(1272, 2077, None))
# box 113: 21.40 render  0.40 write
# (slice(1269, 2073, None), slice(287, 1092, None), slice(1511, 2304, None))
# box 114: 20.92 render  0.48 write
# (slice(1268, 2072, None), slice(763, 1565, None), slice(0, 556, None))
# (slice(1285, 2088, None), slice(0, 507, None), slice(0, 565, None))
# box 115: 36.86 render  0.42 write
# (slice(1262, 2072, None), slice(763, 1572, None), slice(233, 1035, None))
# (slice(1285, 2094, None), slice(0, 507, None), slice(242, 1052, None))
# box 116: 40.12 render  0.44 write
# (slice(1262, 2071, None), slice(765, 1573, None), slice(710, 1516, None))
# (slice(1284, 2094, None), slice(0, 502, None), slice(722, 1533, None))
# box 117: 38.04 render  0.43 write
# (slice(1264, 2074, None), slice(767, 1573, None), slice(1268, 2080, None))
# (slice(1280, 2092, None), slice(0, 506, None), slice(1288, 2090, None))
# box 118: 40.98 render  0.45 write
# (slice(1269, 2074, None), slice(767, 1571, None), slice(1511, 2304, None))
# (slice(1278, 2088, None), slice(0, 506, None), slice(1524, 2304, None))
# box 119: 40.75 render  0.35 write
# (slice(1265, 2072, None), slice(1322, 2129, None), slice(0, 555, None))
# (slice(1285, 2087, None), slice(181, 986, None), slice(0, 568, None))
# box 120: 37.52 render  0.41 write
# (slice(1260, 2072, None), slice(1322, 2133, None), slice(229, 1032, None))
# (slice(1285, 2094, None), slice(174, 984, None), slice(242, 1053, None))
# box 121: 40.64 render  0.94 write
# (slice(1260, 2070, None), slice(1325, 2133, None), slice(705, 1519, None))
# (slice(1283, 2094, None), slice(173, 983, None), slice(723, 1531, None))
# box 122: 39.43 render  0.46 write
# (slice(1264, 2074, None), slice(1324, 2129, None), slice(1268, 2080, None))
# (slice(1280, 2092, None), slice(173, 984, None), slice(1284, 2087, None))
# box 123: 39.25 render  0.49 write
# (slice(1269, 2074, None), slice(1324, 2126, None), slice(1511, 2304, None))
# (slice(1278, 2087, None), slice(174, 984, None), slice(1523, 2304, None))
# box 124: 39.18 render  0.44 write
# (slice(1265, 2072, None), slice(1801, 2289, None), slice(0, 553, None))
# (slice(1285, 2086, None), slice(658, 1463, None), slice(0, 569, None))
# box 125: 32.51 render  0.41 write
# (slice(1260, 2072, None), slice(1801, 2293, None), slice(229, 1032, None))
# (slice(1285, 2094, None), slice(654, 1462, None), slice(242, 1053, None))
# box 126: 36.12 render  0.55 write
# (slice(1260, 2069, None), slice(1804, 2293, None), slice(705, 1519, None))
# (slice(1282, 2094, None), slice(654, 1463, None), slice(725, 1527, None))
# box 127: 33.79 render  0.42 write
# (slice(1266, 2074, None), slice(1802, 2289, None), slice(1268, 2080, None))
# (slice(1280, 2092, None), slice(656, 1463, None), slice(1284, 2085, None))
# box 128: 33.75 render  0.40 write
# (slice(1270, 2074, None), slice(1802, 2286, None), slice(1514, 2304, None))
# (slice(1279, 2086, None), slice(659, 1463, None), slice(1523, 2304, None))
# box 129: 33.27 render  0.45 write
# (slice(1283, 2086, None), slice(1217, 2022, None), slice(0, 569, None))
# box 130: 20.20 render  0.35 write
# (slice(1283, 2088, None), slice(1217, 2022, None), slice(244, 1048, None))
# box 131: 22.90 render  0.42 write
# (slice(1281, 2088, None), slice(1217, 2022, None), slice(724, 1526, None))
# box 132: 21.48 render  0.36 write
# (slice(1279, 2087, None), slice(1220, 2023, None), slice(1283, 2085, None))
# box 133: 20.90 render  0.37 write
# (slice(1278, 2085, None), slice(1220, 2023, None), slice(1523, 2304, None))
# box 134: 20.65 render  0.36 write
# (slice(1283, 2085, None), slice(1618, 2263, None), slice(0, 568, None))
# box 135: 20.56 render  0.58 write
# (slice(1282, 2085, None), slice(1618, 2263, None), slice(244, 1047, None))
# box 136: 21.65 render  0.55 write
# (slice(1281, 2085, None), slice(1619, 2263, None), slice(724, 1526, None))
# box 137: 21.66 render  0.58 write
# (slice(1279, 2085, None), slice(1620, 2263, None), slice(1283, 2085, None))
# box 138: 20.10 render  0.56 write
# (slice(1278, 2084, None), slice(1620, 2263, None), slice(1523, 2304, None))
# box 139: 20.52 render  0.57 write
# (slice(1750, 2554, None), slice(0, 608, None), slice(0, 557, None))
# box 140: 20.65 render  0.36 write
# (slice(1750, 2554, None), slice(0, 610, None), slice(235, 1037, None))
# box 141: 20.27 render  0.89 write
# (slice(1750, 2553, None), slice(0, 611, None), slice(715, 1517, None))
# box 142: 21.14 render  0.47 write
# (slice(1750, 2553, None), slice(0, 613, None), slice(1274, 2077, None))
# box 143: 20.55 render  0.54 write
# (slice(1750, 2553, None), slice(0, 613, None), slice(1514, 2304, None))
# box 144: 21.23 render  0.50 write
# (slice(1749, 2553, None), slice(284, 1087, None), slice(0, 557, None))
# box 145: 21.92 render  0.63 write
# (slice(1747, 2553, None), slice(285, 1090, None), slice(234, 1037, None))
# box 146: 22.39 render  0.57 write
# (slice(1747, 2553, None), slice(286, 1093, None), slice(714, 1516, None))
# box 147: 21.01 render  1.03 write
# (slice(1747, 2553, None), slice(287, 1093, None), slice(1272, 2075, None))
# box 148: 21.75 render  0.46 write
# (slice(1749, 2553, None), slice(288, 1093, None), slice(1511, 2304, None))
# box 149: 21.26 render  0.70 write
# (slice(1748, 2554, None), slice(764, 1566, None), slice(0, 556, None))
# (slice(1765, 2567, None), slice(0, 508, None), slice(0, 565, None))
# box 150: 37.16 render  0.42 write
# (slice(1741, 2553, None), slice(764, 1573, None), slice(233, 1036, None))
# (slice(1765, 2572, None), slice(0, 508, None), slice(241, 1052, None))
# box 151: 39.92 render  0.53 write
# (slice(1741, 2551, None), slice(766, 1574, None), slice(711, 1514, None))
# (slice(1766, 2573, None), slice(0, 504, None), slice(722, 1532, None))
# box 152: 38.59 render  0.75 write
# (slice(1743, 2555, None), slice(768, 1574, None), slice(1268, 2079, None))
# (slice(1760, 2573, None), slice(0, 506, None), slice(1288, 2090, None))
# box 153: 40.29 render  0.76 write
# (slice(1747, 2555, None), slice(769, 1573, None), slice(1511, 2304, None))
# (slice(1758, 2568, None), slice(0, 506, None), slice(1527, 2304, None))
# box 154: 38.01 render  0.42 write
# (slice(1747, 2554, None), slice(1323, 2128, None), slice(0, 556, None))
# (slice(1764, 2566, None), slice(183, 987, None), slice(0, 568, None))
# box 155: 37.23 render  0.55 write
# (slice(1739, 2553, None), slice(1323, 2135, None), slice(230, 1032, None))
# (slice(1764, 2573, None), slice(175, 986, None), slice(241, 1053, None))
# box 156: 40.86 render  0.90 write
# (slice(1739, 2551, None), slice(1325, 2135, None), slice(705, 1518, None))
# (slice(1763, 2573, None), slice(173, 983, None), slice(723, 1531, None))
# box 157: 38.79 render  0.87 write
# (slice(1743, 2555, None), slice(1325, 2132, None), slice(1267, 2080, None))
# (slice(1760, 2573, None), slice(173, 985, None), slice(1286, 2087, None))
# box 158: 40.53 render  0.96 write
# (slice(1747, 2555, None), slice(1325, 2127, None), slice(1511, 2304, None))
# (slice(1758, 2568, None), slice(174, 985, None), slice(1524, 2304, None))
# box 159: 38.70 render  0.37 write
# (slice(1747, 2553, None), slice(1801, 2288, None), slice(0, 554, None))
# (slice(1764, 2566, None), slice(661, 1465, None), slice(0, 569, None))
# box 160: 33.57 render  0.57 write
# (slice(1739, 2552, None), slice(1801, 2295, None), slice(230, 1029, None))
# (slice(1764, 2573, None), slice(655, 1464, None), slice(242, 1053, None))
# box 161: 34.75 render  0.52 write
# (slice(1739, 2548, None), slice(1807, 2295, None), slice(705, 1518, None))
# (slice(1763, 2573, None), slice(655, 1464, None), slice(726, 1528, None))
# box 162: 34.22 render  0.57 write
# (slice(1743, 2555, None), slice(1803, 2292, None), slice(1267, 2080, None))
# (slice(1760, 2573, None), slice(656, 1464, None), slice(1285, 2086, None))
# box 163: 33.17 render  0.67 write
# (slice(1748, 2555, None), slice(1803, 2287, None), slice(1512, 2304, None))
# (slice(1759, 2568, None), slice(659, 1464, None), slice(1524, 2304, None))
# box 164: 33.74 render  0.40 write
# (slice(1763, 2566, None), slice(1219, 2024, None), slice(0, 569, None))
# box 165: 20.14 render  0.34 write
# (slice(1763, 2568, None), slice(1218, 2024, None), slice(246, 1048, None))
# box 166: 21.21 render  2.27 write
# (slice(1762, 2568, None), slice(1218, 2024, None), slice(725, 1527, None))
# box 167: 22.15 render  0.65 write
# (slice(1760, 2567, None), slice(1221, 2023, None), slice(1285, 2086, None))
# box 168: 20.84 render  0.47 write
# (slice(1759, 2566, None), slice(1221, 2024, None), slice(1524, 2304, None))
# box 169: 21.27 render  0.39 write
# (slice(1763, 2565, None), slice(1620, 2264, None), slice(0, 568, None))
# box 170: 19.86 render  0.55 write
# (slice(1763, 2565, None), slice(1620, 2264, None), slice(246, 1047, None))
# box 171: 20.44 render  0.60 write
# (slice(1762, 2565, None), slice(1620, 2264, None), slice(725, 1527, None))
# box 172: 20.67 render  0.53 write
# (slice(1760, 2565, None), slice(1621, 2263, None), slice(1285, 2086, None))
# box 173: 21.60 render  0.61 write
# (slice(1759, 2565, None), slice(1621, 2264, None), slice(1524, 2304, None))
# box 174: 20.80 render  0.55 write
# (slice(2311, 3114, None), slice(0, 609, None), slice(0, 558, None))
# box 175: 19.85 render  0.47 write
# (slice(2310, 3114, None), slice(0, 610, None), slice(235, 1037, None))
# box 176: 20.32 render  0.37 write
# (slice(2310, 3114, None), slice(0, 612, None), slice(715, 1517, None))
# box 177: 20.91 render  0.53 write
# (slice(2310, 3113, None), slice(0, 614, None), slice(1274, 2077, None))
# box 178: 20.77 render  0.45 write
# (slice(2311, 3113, None), slice(0, 614, None), slice(1514, 2304, None))
# box 179: 20.47 render  0.40 write
# (slice(2310, 3114, None), slice(285, 1088, None), slice(0, 557, None))
# box 180: 19.88 render  0.61 write
# (slice(2308, 3114, None), slice(286, 1091, None), slice(235, 1037, None))
# box 181: 21.69 render  0.44 write
# (slice(2307, 3113, None), slice(287, 1094, None), slice(714, 1516, None))
# box 182: 21.48 render  0.51 write
# (slice(2308, 3113, None), slice(289, 1094, None), slice(1272, 2075, None))
# box 183: 22.73 render  0.39 write
# (slice(2309, 3113, None), slice(289, 1094, None), slice(1511, 2304, None))
# box 184: 21.05 render  0.61 write
# (slice(2310, 3114, None), slice(765, 1568, None), slice(0, 556, None))
# (slice(2323, 3126, None), slice(0, 509, None), slice(0, 564, None))
# box 185: 37.72 render  0.39 write
# (slice(2302, 3114, None), slice(766, 1574, None), slice(234, 1036, None))
# (slice(2324, 3132, None), slice(0, 508, None), slice(240, 1052, None))
# box 186: 39.15 render  0.49 write
# (slice(2302, 3112, None), slice(767, 1575, None), slice(713, 1514, None))
# (slice(2326, 3133, None), slice(0, 505, None), slice(720, 1531, None))
# box 187: 39.93 render  0.75 write
# (slice(2302, 3115, None), slice(769, 1575, None), slice(1268, 2079, None))
# (slice(2321, 3131, None), slice(0, 507, None), slice(1287, 2090, None))
# box 188: 38.14 render  0.54 write
# (slice(2308, 3115, None), slice(770, 1574, None), slice(1510, 2304, None))
# (slice(2318, 3128, None), slice(0, 507, None), slice(1527, 2304, None))
# box 189: 39.05 render  0.86 write
# (slice(2307, 3114, None), slice(1324, 2129, None), slice(0, 556, None))
# (slice(2323, 3125, None), slice(185, 988, None), slice(0, 568, None))
# box 190: 36.94 render  0.34 write
# (slice(2299, 3114, None), slice(1324, 2135, None), slice(231, 1032, None))
# (slice(2323, 3133, None), slice(178, 987, None), slice(240, 1052, None))
# box 191: 40.95 render  0.55 write
# (slice(2299, 3112, None), slice(1326, 2135, None), slice(706, 1518, None))
# (slice(2324, 3133, None), slice(175, 984, None), slice(722, 1530, None))
# box 192: 40.19 render  0.66 write
# (slice(2301, 3115, None), slice(1326, 2133, None), slice(1267, 2080, None))
# (slice(2321, 3131, None), slice(175, 985, None), slice(1287, 2087, None))
# box 193: 38.96 render  0.47 write
# (slice(2307, 3115, None), slice(1326, 2130, None), slice(1510, 2304, None))
# (slice(2318, 3128, None), slice(176, 985, None), slice(1525, 2304, None))
# box 194: 39.19 render  0.68 write
# (slice(2307, 3114, None), slice(1801, 2289, None), slice(0, 555, None))
# (slice(2323, 3125, None), slice(664, 1466, None), slice(0, 569, None))
# box 195: 32.28 render  0.39 write
# (slice(2299, 3114, None), slice(1801, 2295, None), slice(231, 1028, None))
# (slice(2323, 3133, None), slice(657, 1465, None), slice(241, 1052, None))
# box 196: 36.40 render  0.43 write
# (slice(2299, 3110, None), slice(1807, 2295, None), slice(706, 1518, None))
# (slice(2324, 3133, None), slice(657, 1464, None), slice(725, 1528, None))
# box 197: 34.29 render  0.82 write
# (slice(2301, 3115, None), slice(1804, 2293, None), slice(1267, 2080, None))
# (slice(2321, 3131, None), slice(657, 1465, None), slice(1286, 2086, None))
# box 198: 33.83 render  0.41 write
# (slice(2307, 3115, None), slice(1804, 2290, None), slice(1511, 2304, None))
# (slice(2319, 3127, None), slice(659, 1465, None), slice(1525, 2304, None))
# box 199: 33.39 render  0.66 write
# (slice(2323, 3125, None), slice(1220, 2025, None), slice(0, 569, None))
# box 200: 20.38 render  0.39 write
# (slice(2323, 3127, None), slice(1219, 2025, None), slice(245, 1048, None))
# box 201: 21.91 render  0.45 write
# (slice(2322, 3127, None), slice(1219, 2025, None), slice(726, 1527, None))
# box 202: 20.88 render  0.38 write
# (slice(2321, 3127, None), slice(1221, 2024, None), slice(1286, 2087, None))
# box 203: 20.85 render  0.40 write
# (slice(2319, 3126, None), slice(1222, 2025, None), slice(1525, 2304, None))
# box 204: 21.45 render  0.34 write
# (slice(2323, 3124, None), slice(1621, 2265, None), slice(0, 568, None))
# box 205: 19.17 render  0.59 write
# (slice(2323, 3125, None), slice(1621, 2265, None), slice(247, 1047, None))
# box 206: 20.96 render  0.49 write
# (slice(2322, 3125, None), slice(1621, 2265, None), slice(726, 1527, None))
# box 207: 20.77 render  0.52 write
# (slice(2321, 3125, None), slice(1622, 2264, None), slice(1286, 2087, None))
# box 208: 20.36 render  0.61 write
# (slice(2319, 3125, None), slice(1622, 2265, None), slice(1525, 2304, None))
# box 209: 19.63 render  0.65 write
# (slice(2792, 3594, None), slice(0, 610, None), slice(0, 558, None))
# box 210: 20.43 render  0.39 write
# (slice(2791, 3594, None), slice(0, 611, None), slice(236, 1037, None))
# box 211: 20.44 render  0.52 write
# (slice(2791, 3594, None), slice(0, 613, None), slice(715, 1517, None))
# box 212: 20.46 render  0.46 write
# (slice(2791, 3594, None), slice(0, 614, None), slice(1274, 2077, None))
# box 213: 20.86 render  0.98 write
# (slice(2791, 3594, None), slice(0, 615, None), slice(1514, 2304, None))
# box 214: 20.54 render  0.41 write
# (slice(2791, 3594, None), slice(287, 1089, None), slice(0, 557, None))
# box 215: 20.30 render  0.43 write
# (slice(2788, 3594, None), slice(287, 1091, None), slice(235, 1037, None))
# box 216: 22.32 render  0.44 write
# (slice(2788, 3594, None), slice(288, 1094, None), slice(715, 1516, None))
# box 217: 21.05 render  0.53 write
# (slice(2788, 3594, None), slice(289, 1094, None), slice(1272, 2076, None))
# box 218: 21.79 render  0.42 write
# (slice(2790, 3594, None), slice(290, 1094, None), slice(1511, 2304, None))
# box 219: 21.26 render  0.43 write
# (slice(2791, 3595, None), slice(766, 1568, None), slice(0, 557, None))
# (slice(2802, 3605, None), slice(0, 510, None), slice(0, 564, None))
# box 220: 36.39 render  0.35 write
# (slice(2783, 3595, None), slice(767, 1574, None), slice(235, 1036, None))
# (slice(2802, 3610, None), slice(0, 509, None), slice(240, 1051, None))
# box 221: 41.84 render  0.56 write
# (slice(2783, 3593, None), slice(768, 1576, None), slice(713, 1514, None))
# (slice(2806, 3612, None), slice(0, 507, None), slice(720, 1531, None))
# box 222: 40.25 render  0.43 write
# (slice(2783, 3595, None), slice(770, 1576, None), slice(1268, 2078, None))
# (slice(2801, 3611, None), slice(0, 507, None), slice(1285, 2089, None))
# box 223: 38.27 render  0.51 write
# (slice(2787, 3595, None), slice(771, 1574, None), slice(1510, 2304, None))
# (slice(2799, 3608, None), slice(0, 507, None), slice(1526, 2304, None))
# box 224: 38.34 render  0.39 write
# (slice(2789, 3595, None), slice(1325, 2130, None), slice(0, 557, None))
# (slice(2802, 3604, None), slice(187, 989, None), slice(0, 567, None))
# box 225: 37.46 render  0.77 write
# (slice(2779, 3595, None), slice(1325, 2135, None), slice(233, 1033, None))
# (slice(2802, 3611, None), slice(180, 988, None), slice(240, 1052, None))
# box 226: 39.06 render  0.45 write
# (slice(2779, 3593, None), slice(1327, 2135, None), slice(707, 1516, None))
# (slice(2806, 3612, None), slice(176, 984, None), slice(721, 1530, None))
# box 227: 40.39 render  0.46 write
# (slice(2781, 3595, None), slice(1327, 2133, None), slice(1268, 2079, None))
# (slice(2801, 3611, None), slice(176, 986, None), slice(1287, 2086, None))
# box 228: 39.77 render  0.51 write
# (slice(2786, 3595, None), slice(1327, 2131, None), slice(1510, 2304, None))
# (slice(2799, 3607, None), slice(177, 986, None), slice(1525, 2304, None))
# box 229: 38.49 render  0.50 write
# (slice(2789, 3595, None), slice(1804, 2290, None), slice(0, 556, None))
# (slice(2802, 3604, None), slice(664, 1467, None), slice(0, 568, None))
# box 230: 35.05 render  0.49 write
# (slice(2779, 3595, None), slice(1804, 2295, None), slice(233, 1030, None))
# (slice(2802, 3611, None), slice(658, 1466, None), slice(241, 1052, None))
# box 231: 33.95 render  0.40 write
# (slice(2779, 3592, None), slice(1809, 2295, None), slice(707, 1516, None))
# (slice(2804, 3612, None), slice(657, 1465, None), slice(724, 1528, None))
# box 232: 35.73 render  0.51 write
# (slice(2781, 3595, None), slice(1805, 2293, None), slice(1268, 2079, None))
# (slice(2801, 3611, None), slice(658, 1465, None), slice(1285, 2086, None))
# box 233: 33.63 render  0.53 write
# (slice(2786, 3595, None), slice(1805, 2291, None), slice(1511, 2304, None))
# (slice(2799, 3607, None), slice(659, 1466, None), slice(1525, 2304, None))
# box 234: 35.11 render  0.44 write
# (slice(2802, 3604, None), slice(1221, 2026, None), slice(0, 568, None))
# box 235: 20.33 render  0.38 write
# (slice(2803, 3607, None), slice(1220, 2026, None), slice(245, 1048, None))
# box 236: 21.81 render  0.45 write
# (slice(2803, 3607, None), slice(1220, 2025, None), slice(726, 1527, None))
# box 237: 21.47 render  0.41 write
# (slice(2802, 3607, None), slice(1222, 2025, None), slice(1285, 2087, None))
# box 238: 20.63 render  0.37 write
# (slice(2799, 3606, None), slice(1223, 2025, None), slice(1525, 2304, None))
# box 239: 21.24 render  0.45 write
# (slice(2802, 3604, None), slice(1622, 2266, None), slice(0, 568, None))
# box 240: 19.97 render  0.55 write
# (slice(2802, 3605, None), slice(1622, 2266, None), slice(247, 1047, None))
# box 241: 22.05 render  0.61 write
# (slice(2803, 3605, None), slice(1622, 2265, None), slice(726, 1527, None))
# box 242: 20.10 render  0.64 write
# (slice(2802, 3605, None), slice(1623, 2265, None), slice(1286, 2087, None))
# box 243: 20.47 render  0.90 write
# (slice(2799, 3605, None), slice(1623, 2265, None), slice(1525, 2304, None))
# box 244: 21.15 render  0.62 write
# (slice(3272, 4075, None), slice(0, 610, None), slice(0, 558, None))
# box 245: 19.67 render  0.51 write
# (slice(3271, 4075, None), slice(0, 611, None), slice(236, 1037, None))
# box 246: 20.39 render  0.43 write
# (slice(3271, 4074, None), slice(0, 613, None), slice(716, 1517, None))
# box 247: 21.91 render  0.43 write
# (slice(3271, 4074, None), slice(0, 615, None), slice(1275, 2077, None))
# box 248: 20.67 render  0.47 write
# (slice(3271, 4074, None), slice(0, 615, None), slice(1514, 2304, None))
# box 249: 20.03 render  0.43 write
# (slice(3272, 4074, None), slice(287, 1090, None), slice(0, 557, None))
# box 250: 21.54 render  0.35 write
# (slice(3269, 4074, None), slice(288, 1092, None), slice(235, 1037, None))
# box 251: 21.00 render  0.46 write
# (slice(3269, 4074, None), slice(289, 1094, None), slice(715, 1516, None))
# box 252: 21.03 render  5.38 write
# (slice(3269, 4074, None), slice(290, 1094, None), slice(1272, 2076, None))
# box 253: 23.06 render  0.46 write
# (slice(3270, 4074, None), slice(291, 1094, None), slice(1511, 2304, None))
# box 254: 21.00 render  0.43 write
# (slice(3272, 4075, None), slice(767, 1569, None), slice(0, 557, None))
# (slice(3282, 4085, None), slice(0, 511, None), slice(0, 563, None))
# box 255: 38.20 render  0.38 write
# (slice(3264, 4075, None), slice(768, 1574, None), slice(235, 1036, None))
# (slice(3282, 4091, None), slice(0, 510, None), slice(240, 1050, None))
# box 256: 37.62 render  0.43 write
# (slice(3264, 4074, None), slice(769, 1576, None), slice(714, 1515, None))
# (slice(3285, 4092, None), slice(0, 508, None), slice(720, 1530, None))
# box 257: 39.81 render  0.45 write
# (slice(3264, 4076, None), slice(771, 1576, None), slice(1269, 2077, None))
# (slice(3282, 4091, None), slice(0, 508, None), slice(1285, 2089, None))
# box 258: 38.55 render  0.46 write
# (slice(3268, 4076, None), slice(772, 1574, None), slice(1511, 2304, None))
# (slice(3279, 4087, None), slice(0, 508, None), slice(1525, 2304, None))
# box 259: 39.03 render  0.39 write
# (slice(3271, 4075, None), slice(1327, 2130, None), slice(0, 557, None))
# (slice(3282, 4085, None), slice(188, 990, None), slice(0, 566, None))
# box 260: 37.44 render  0.36 write
# (slice(3261, 4075, None), slice(1327, 2136, None), slice(234, 1034, None))
# (slice(3282, 4091, None), slice(181, 989, None), slice(240, 1051, None))
# box 261: 40.61 render  0.42 write
# (slice(3261, 4074, None), slice(1328, 2136, None), slice(710, 1517, None))
# (slice(3285, 4092, None), slice(177, 985, None), slice(721, 1529, None))
# box 262: 38.43 render  0.44 write
# (slice(3262, 4076, None), slice(1328, 2134, None), slice(1268, 2079, None))
# (slice(3282, 4091, None), slice(177, 986, None), slice(1286, 2086, None))
# box 263: 39.96 render  0.46 write
# (slice(3267, 4076, None), slice(1328, 2131, None), slice(1511, 2304, None))
# (slice(3279, 4087, None), slice(178, 986, None), slice(1524, 2304, None))
# box 264: 40.10 render  0.42 write
# (slice(3271, 4075, None), slice(1805, 2290, None), slice(0, 556, None))
# (slice(3282, 4085, None), slice(666, 1468, None), slice(0, 568, None))
# box 265: 34.47 render  0.42 write
# (slice(3261, 4075, None), slice(1806, 2296, None), slice(234, 1031, None))
# (slice(3282, 4091, None), slice(659, 1467, None), slice(241, 1051, None))
# box 266: 33.56 render  0.37 write
# (slice(3261, 4073, None), slice(1809, 2296, None), slice(710, 1517, None))
# (slice(3284, 4092, None), slice(659, 1466, None), slice(724, 1527, None))
# box 267: 34.70 render  0.49 write
# (slice(3262, 4075, None), slice(1806, 2294, None), slice(1268, 2079, None))
# (slice(3282, 4091, None), slice(659, 1466, None), slice(1285, 2086, None))
# box 268: 34.22 render  0.52 write
# (slice(3267, 4075, None), slice(1806, 2291, None), slice(1511, 2304, None))
# (slice(3279, 4087, None), slice(661, 1466, None), slice(1524, 2304, None))
# box 269: 34.92 render  0.68 write
# (slice(3282, 4085, None), slice(1223, 2027, None), slice(0, 568, None))
# box 270: 20.59 render  0.46 write
# (slice(3282, 4087, None), slice(1221, 2026, None), slice(245, 1048, None))
# box 271: 20.98 render  0.55 write
# (slice(3283, 4087, None), slice(1221, 2026, None), slice(726, 1527, None))
# box 272: 21.53 render  0.44 write
# (slice(3283, 4087, None), slice(1223, 2026, None), slice(1285, 2087, None))
# box 273: 22.38 render  0.40 write
# (slice(3279, 4086, None), slice(1223, 2026, None), slice(1525, 2304, None))
# box 274: 21.91 render  0.34 write
# (slice(3282, 4084, None), slice(1623, 2267, None), slice(0, 568, None))
# box 275: 19.43 render  0.59 write
# (slice(3282, 4085, None), slice(1623, 2266, None), slice(247, 1047, None))
# box 276: 20.25 render  0.57 write
# (slice(3283, 4085, None), slice(1623, 2266, None), slice(726, 1527, None))
# box 277: 20.96 render  0.62 write
# (slice(3283, 4085, None), slice(1623, 2266, None), slice(1285, 2087, None))
# box 278: 20.55 render  0.51 write
# (slice(3279, 4085, None), slice(1623, 2266, None), slice(1525, 2304, None))
# box 279: 19.82 render  0.58 write
# (slice(3833, 4635, None), slice(0, 611, None), slice(0, 557, None))
# box 280: 19.93 render  0.52 write
# (slice(3832, 4635, None), slice(0, 612, None), slice(236, 1037, None))
# box 281: 21.10 render  0.38 write
# (slice(3832, 4635, None), slice(0, 613, None), slice(716, 1517, None))
# box 282: 20.12 render  0.41 write
# (slice(3832, 4634, None), slice(0, 615, None), slice(1275, 2077, None))
# box 283: 21.02 render  0.57 write
# (slice(3832, 4634, None), slice(0, 615, None), slice(1514, 2304, None))
# box 284: 20.23 render  0.36 write
# (slice(3833, 4635, None), slice(288, 1090, None), slice(0, 557, None))
# box 285: 20.21 render  0.40 write
# (slice(3831, 4635, None), slice(289, 1092, None), slice(235, 1037, None))
# box 286: 22.19 render  0.37 write
# (slice(3830, 4635, None), slice(290, 1095, None), slice(715, 1517, None))
# box 287: 21.30 render  0.46 write
# (slice(3830, 4635, None), slice(291, 1095, None), slice(1273, 2076, None))
# box 288: 21.62 render  0.49 write
# (slice(3831, 4635, None), slice(291, 1095, None), slice(1512, 2304, None))
# box 289: 22.23 render  0.38 write
# (slice(3833, 4636, None), slice(768, 1570, None), slice(0, 557, None))
# (slice(3842, 4646, None), slice(0, 512, None), slice(0, 563, None))
# box 290: 38.52 render  0.41 write
# (slice(3827, 4636, None), slice(768, 1575, None), slice(235, 1036, None))
# (slice(3842, 4651, None), slice(0, 511, None), slice(240, 1048, None))
# box 291: 38.01 render  0.37 write
# (slice(3825, 4634, None), slice(769, 1576, None), slice(714, 1515, None))
# (slice(3844, 4652, None), slice(0, 509, None), slice(720, 1528, None))
# box 292: 37.97 render  0.52 write
# (slice(3825, 4636, None), slice(771, 1576, None), slice(1270, 2078, None))
# (slice(3842, 4651, None), slice(0, 508, None), slice(1284, 2088, None))
# box 293: 39.96 render  0.42 write
# (slice(3830, 4636, None), slice(772, 1575, None), slice(1511, 2304, None))
# (slice(3839, 4647, None), slice(0, 508, None), slice(1525, 2304, None))
# box 294: 39.21 render  0.44 write
# (slice(3832, 4636, None), slice(1327, 2131, None), slice(0, 557, None))
# (slice(3842, 4645, None), slice(189, 991, None), slice(0, 565, None))
# box 295: 38.64 render  0.39 write
# (slice(3825, 4636, None), slice(1328, 2137, None), slice(234, 1034, None))
# (slice(3842, 4652, None), slice(183, 990, None), slice(240, 1050, None))
# box 296: 39.10 render  0.47 write
# (slice(3823, 4634, None), slice(1328, 2137, None), slice(710, 1517, None))
# (slice(3844, 4652, None), slice(179, 986, None), slice(721, 1527, None))
# box 297: 40.13 render  0.47 write
# (slice(3824, 4636, None), slice(1329, 2135, None), slice(1269, 2079, None))
# (slice(3842, 4651, None), slice(179, 987, None), slice(1286, 2085, None))
# box 298: 39.03 render  0.44 write
# (slice(3829, 4636, None), slice(1329, 2132, None), slice(1511, 2304, None))
# (slice(3839, 4647, None), slice(180, 987, None), slice(1524, 2304, None))
# box 299: 39.05 render  0.64 write
# (slice(3832, 4636, None), slice(1807, 2291, None), slice(0, 556, None))
# (slice(3842, 4645, None), slice(667, 1469, None), slice(0, 567, None))
# box 300: 32.32 render  0.56 write
# (slice(3825, 4636, None), slice(1807, 2297, None), slice(234, 1031, None))
# (slice(3842, 4652, None), slice(661, 1467, None), slice(241, 1050, None))
# box 301: 33.99 render  0.44 write
# (slice(3823, 4633, None), slice(1810, 2297, None), slice(710, 1517, None))
# (slice(3844, 4652, None), slice(660, 1467, None), slice(724, 1526, None))
# box 302: 33.51 render  0.44 write
# (slice(3824, 4636, None), slice(1807, 2295, None), slice(1269, 2079, None))
# (slice(3842, 4651, None), slice(660, 1467, None), slice(1285, 2086, None))
# box 303: 34.04 render  0.46 write
# (slice(3829, 4636, None), slice(1807, 2292, None), slice(1512, 2304, None))
# (slice(3840, 4647, None), slice(662, 1467, None), slice(1524, 2304, None))
# box 304: 34.25 render  0.53 write
# (slice(3842, 4645, None), slice(1224, 2027, None), slice(0, 568, None))
# box 305: 20.19 render  0.57 write
# (slice(3842, 4647, None), slice(1222, 2027, None), slice(245, 1047, None))
# box 306: 21.26 render  0.43 write
# (slice(3843, 4647, None), slice(1222, 2027, None), slice(726, 1527, None))
# box 307: 22.47 render  0.48 write
# (slice(3843, 4647, None), slice(1223, 2027, None), slice(1285, 2086, None))
# box 308: 21.57 render  0.41 write
# (slice(3840, 4646, None), slice(1224, 2027, None), slice(1525, 2304, None))
# box 309: 20.40 render  0.36 write
# (slice(3842, 4645, None), slice(1624, 2267, None), slice(0, 568, None))
# box 310: 19.88 render  0.61 write
# (slice(3842, 4645, None), slice(1624, 2267, None), slice(246, 1047, None))
# box 311: 20.49 render  0.60 write
# (slice(3843, 4645, None), slice(1624, 2267, None), slice(726, 1527, None))
# box 312: 20.70 render  0.57 write
# (slice(3843, 4645, None), slice(1624, 2267, None), slice(1285, 2086, None))
# box 313: 20.50 render  0.44 write
# (slice(3840, 4645, None), slice(1624, 2267, None), slice(1525, 2304, None))
# box 314: 20.06 render  0.59 write
# (slice(4313, 5116, None), slice(0, 611, None), slice(0, 557, None))
# box 315: 19.31 render  0.51 write
# (slice(4313, 5116, None), slice(0, 612, None), slice(236, 1037, None))
# box 316: 21.13 render  0.37 write
# (slice(4313, 5115, None), slice(0, 613, None), slice(716, 1517, None))
# box 317: 19.99 render  0.43 write
# (slice(4313, 5115, None), slice(0, 615, None), slice(1275, 2077, None))
# box 318: 20.54 render  0.45 write
# (slice(4313, 5115, None), slice(0, 615, None), slice(1514, 2304, None))
# box 319: 20.73 render  0.47 write
# (slice(4313, 5116, None), slice(289, 1091, None), slice(0, 557, None))
# box 320: 20.20 render  0.42 write
# (slice(4311, 5116, None), slice(289, 1093, None), slice(235, 1037, None))
# box 321: 21.21 render  1.24 write
# (slice(4311, 5115, None), slice(290, 1095, None), slice(715, 1517, None))
# box 322: 21.74 render  0.56 write
# (slice(4311, 5115, None), slice(291, 1095, None), slice(1273, 2076, None))
# box 323: 23.14 render  0.52 write
# (slice(4312, 5115, None), slice(292, 1095, None), slice(1512, 2304, None))
# box 324: 21.12 render  1.18 write
# (slice(4313, 5117, None), slice(769, 1570, None), slice(0, 557, None))
# (slice(4323, 5126, None), slice(0, 512, None), slice(0, 563, None))
# box 325: 37.44 render  0.43 write
# (slice(4307, 5117, None), slice(769, 1576, None), slice(235, 1037, None))
# (slice(4323, 5132, None), slice(0, 512, None), slice(240, 1049, None))
# box 326: 41.45 render  0.42 write
# (slice(4306, 5115, None), slice(770, 1577, None), slice(714, 1515, None))
# (slice(4324, 5132, None), slice(0, 509, None), slice(720, 1528, None))
# box 327: 38.33 render  0.51 write
# (slice(4307, 5116, None), slice(772, 1577, None), slice(1270, 2078, None))
# (slice(4322, 5131, None), slice(0, 509, None), slice(1284, 2087, None))
# box 328: 39.69 render  0.44 write
# (slice(4310, 5116, None), slice(772, 1576, None), slice(1511, 2304, None))
# (slice(4319, 5127, None), slice(0, 509, None), slice(1525, 2304, None))
# box 329: 37.74 render  0.41 write
# (slice(4313, 5117, None), slice(1328, 2132, None), slice(0, 557, None))
# (slice(4322, 5125, None), slice(190, 992, None), slice(0, 565, None))
# box 330: 38.80 render  0.39 write
# (slice(4305, 5117, None), slice(1328, 2137, None), slice(234, 1034, None))
# (slice(4322, 5132, None), slice(184, 990, None), slice(240, 1050, None))
# box 331: 41.63 render  0.40 write
# (slice(4304, 5114, None), slice(1329, 2137, None), slice(710, 1517, None))
# (slice(4324, 5132, None), slice(180, 987, None), slice(721, 1527, None))
# box 332: 38.96 render  0.48 write
# (slice(4304, 5116, None), slice(1329, 2135, None), slice(1269, 2079, None))
# (slice(4322, 5131, None), slice(180, 988, None), slice(1286, 2085, None))
# box 333: 40.42 render  0.45 write
# (slice(4308, 5116, None), slice(1329, 2132, None), slice(1511, 2304, None))
# (slice(4319, 5127, None), slice(180, 988, None), slice(1524, 2304, None))
# box 334: 38.64 render  0.52 write
# (slice(4313, 5117, None), slice(1807, 2292, None), slice(0, 556, None))
# (slice(4322, 5125, None), slice(668, 1470, None), slice(0, 567, None))
# box 335: 32.36 render  0.35 write
# (slice(4305, 5117, None), slice(1807, 2297, None), slice(234, 1031, None))
# (slice(4322, 5132, None), slice(662, 1468, None), slice(241, 1050, None))
# box 336: 34.44 render  0.46 write
# (slice(4304, 5113, None), slice(1810, 2297, None), slice(710, 1517, None))
# (slice(4324, 5132, None), slice(661, 1468, None), slice(724, 1527, None))
# box 337: 33.88 render  0.46 write
# (slice(4304, 5116, None), slice(1807, 2295, None), slice(1269, 2079, None))
# ...
# box 865: 20.15 render  0.37 write
# (slice(12006, 12810, None), slice(1230, 2033, None), slice(246, 1048, None))
# box 866: 21.01 render  0.41 write
# (slice(12005, 12809, None), slice(1230, 2033, None), slice(725, 1528, None))
# box 867: 22.11 render  0.33 write
# (slice(12004, 12807, None), slice(1231, 2034, None), slice(1285, 2087, None))
# box 868: 22.51 render  0.42 write
# (slice(12004, 12807, None), slice(1231, 2034, None), slice(1525, 2304, None))
# box 869: 20.57 render  0.34 write
# (slice(12007, 12810, None), slice(1629, 2273, None), slice(0, 568, None))
# box 870: 19.40 render  0.68 write
# (slice(12006, 12809, None), slice(1630, 2273, None), slice(246, 1047, None))
# box 871: 21.13 render  0.56 write
# (slice(12005, 12808, None), slice(1631, 2273, None), slice(725, 1528, None))
# box 872: 20.13 render  0.63 write
# (slice(12005, 12807, None), slice(1632, 2274, None), slice(1285, 2087, None))
# box 873: 19.86 render  0.57 write
# (slice(12005, 12807, None), slice(1632, 2274, None), slice(1526, 2304, None))
# box 874: 21.13 render  0.71 write
# (slice(12556, 13361, None), slice(0, 619, None), slice(0, 551, None))
# box 875: 20.35 render  0.33 write
# (slice(12557, 13362, None), slice(0, 619, None), slice(227, 1031, None))
# box 876: 20.45 render  0.45 write
# (slice(12558, 13363, None), slice(0, 619, None), slice(707, 1510, None))
# box 877: 19.99 render  0.66 write
# (slice(12560, 13365, None), slice(0, 619, None), slice(1266, 2070, None))
# box 878: 21.82 render  0.53 write
# (slice(12560, 13365, None), slice(0, 618, None), slice(1506, 2304, None))
# box 879: 20.03 render  0.38 write
# (slice(12556, 13360, None), slice(296, 1099, None), slice(0, 552, None))
# box 880: 20.15 render  0.43 write
# (slice(12556, 13361, None), slice(296, 1101, None), slice(227, 1032, None))
# box 881: 21.63 render  0.43 write
# (slice(12557, 13363, None), slice(295, 1101, None), slice(707, 1511, None))
# box 882: 21.43 render  0.47 write
# (slice(12559, 13364, None), slice(294, 1100, None), slice(1267, 2073, None))
# box 883: 21.74 render  0.69 write
# (slice(12560, 13364, None), slice(294, 1099, None), slice(1506, 2304, None))
# box 884: 22.06 render  0.41 write
# (slice(12555, 13358, None), slice(776, 1582, None), slice(0, 553, None))
# (slice(12564, 13371, None), slice(0, 517, None), slice(0, 573, None))
# box 885: 36.60 render  0.33 write
# (slice(12555, 13359, None), slice(776, 1583, None), slice(227, 1032, None))
# (slice(12564, 13370, None), slice(0, 516, None), slice(242, 1051, None))
# box 886: 39.13 render  0.44 write
# (slice(12555, 13361, None), slice(776, 1583, None), slice(704, 1514, None))
# (slice(12563, 13370, None), slice(0, 512, None), slice(722, 1528, None))
# box 887: 38.08 render  0.42 write
# (slice(12557, 13363, None), slice(773, 1580, None), slice(1267, 2078, None))
# (slice(12562, 13366, None), slice(0, 513, None), slice(1286, 2085, None))
# box 888: 38.69 render  0.47 write
# (slice(12559, 13363, None), slice(772, 1576, None), slice(1507, 2304, None))
# (slice(12562, 13365, None), slice(0, 513, None), slice(1524, 2304, None))
# box 889: 39.15 render  0.50 write
# (slice(12552, 13356, None), slice(1335, 2143, None), slice(0, 553, None))
# (slice(12565, 13371, None), slice(189, 993, None), slice(0, 573, None))
# box 890: 38.24 render  0.55 write
# (slice(12552, 13358, None), slice(1335, 2143, None), slice(224, 1032, None))
# (slice(12565, 13370, None), slice(185, 992, None), slice(243, 1051, None))
# box 891: 39.28 render  0.44 write
# (slice(12553, 13360, None), slice(1336, 2142, None), slice(704, 1517, None))
# (slice(12563, 13370, None), slice(185, 994, None), slice(724, 1527, None))
# box 892: 42.60 render  0.47 write
# (slice(12557, 13362, None), slice(1331, 2136, None), slice(1268, 2079, None))
# (slice(12562, 13366, None), slice(186, 994, None), slice(1286, 2085, None))
# box 893: 38.96 render  0.43 write
# (slice(12559, 13362, None), slice(1330, 2133, None), slice(1511, 2304, None))
# (slice(12562, 13365, None), slice(189, 994, None), slice(1524, 2304, None))
# box 894: 40.07 render  0.52 write
# (slice(12552, 13355, None), slice(1815, 2303, None), slice(0, 549, None))
# (slice(12566, 13371, None), slice(667, 1472, None), slice(0, 573, None))
# box 895: 31.84 render  0.44 write
# (slice(12552, 13358, None), slice(1816, 2303, None), slice(224, 1032, None))
# (slice(12566, 13370, None), slice(667, 1473, None), slice(245, 1051, None))
# box 896: 34.64 render  0.34 write
# (slice(12553, 13360, None), slice(1813, 2302, None), slice(704, 1517, None))
# (slice(12564, 13370, None), slice(667, 1474, None), slice(727, 1528, None))
# box 897: 36.16 render  0.51 write
# (slice(12557, 13362, None), slice(1810, 2296, None), slice(1269, 2079, None))
# (slice(12563, 13367, None), slice(669, 1474, None), slice(1286, 2088, None))
# box 898: 34.21 render  0.88 write
# (slice(12559, 13362, None), slice(1810, 2293, None), slice(1514, 2304, None))
# (slice(12563, 13367, None), slice(671, 1474, None), slice(1524, 2304, None))
# box 899: 34.03 render  0.46 write
# (slice(12567, 13370, None), slice(1229, 2033, None), slice(0, 570, None))
# box 900: 19.68 render  0.34 write
# (slice(12567, 13370, None), slice(1230, 2033, None), slice(246, 1049, None))
# box 901: 21.13 render  0.41 write
# (slice(12565, 13369, None), slice(1230, 2033, None), slice(726, 1529, None))
# box 902: 21.67 render  0.33 write
# (slice(12564, 13368, None), slice(1231, 2034, None), slice(1286, 2088, None))
# box 903: 20.84 render  0.39 write
# (slice(12564, 13367, None), slice(1231, 2034, None), slice(1525, 2304, None))
# box 904: 21.03 render  0.35 write
# (slice(12567, 13370, None), slice(1629, 2273, None), slice(0, 569, None))
# box 905: 19.70 render  0.51 write
# (slice(12567, 13370, None), slice(1630, 2273, None), slice(246, 1048, None))
# box 906: 20.04 render  0.70 write
# (slice(12566, 13369, None), slice(1632, 2273, None), slice(726, 1529, None))
# box 907: 20.03 render  0.71 write
# (slice(12565, 13368, None), slice(1631, 2274, None), slice(1286, 2088, None))
# box 908: 20.25 render  3.79 write
# (slice(12565, 13367, None), slice(1631, 2274, None), slice(1526, 2304, None))
# box 909: 20.31 render  0.48 write
# (slice(13036, 13841, None), slice(0, 621, None), slice(0, 550, None))
# box 910: 19.92 render  0.42 write
# (slice(13037, 13842, None), slice(0, 621, None), slice(226, 1030, None))
# box 911: 20.69 render  0.37 write
# (slice(13038, 13844, None), slice(0, 621, None), slice(705, 1509, None))
# box 912: 20.39 render  0.50 write
# (slice(13040, 13846, None), slice(0, 621, None), slice(1264, 2069, None))
# box 913: 21.08 render  0.43 write
# (slice(13041, 13846, None), slice(0, 620, None), slice(1504, 2304, None))
# box 914: 20.30 render  0.41 write
# (slice(13035, 13840, None), slice(297, 1102, None), slice(0, 550, None))
# box 915: 21.32 render  0.47 write
# (slice(13036, 13841, None), slice(297, 1102, None), slice(226, 1030, None))
# box 916: 21.95 render  0.48 write
# (slice(13037, 13843, None), slice(296, 1102, None), slice(705, 1510, None))
# box 917: 21.04 render  0.43 write
# (slice(13039, 13845, None), slice(294, 1101, None), slice(1265, 2073, None))
# box 918: 22.53 render  0.43 write
# (slice(13040, 13845, None), slice(294, 1099, None), slice(1504, 2304, None))
# box 919: 22.92 render  0.39 write
# (slice(13034, 13838, None), slice(777, 1583, None), slice(0, 550, None))
# (slice(13045, 13851, None), slice(0, 515, None), slice(0, 574, None))
# box 920: 37.26 render  0.41 write
# (slice(13034, 13839, None), slice(777, 1583, None), slice(225, 1030, None))
# (slice(13045, 13850, None), slice(0, 513, None), slice(245, 1052, None))
# box 921: 39.61 render  0.85 write
# (slice(13034, 13841, None), slice(777, 1583, None), slice(703, 1514, None))
# (slice(13043, 13849, None), slice(0, 512, None), slice(725, 1529, None))
# box 922: 38.67 render  0.50 write
# (slice(13037, 13843, None), slice(773, 1580, None), slice(1265, 2078, None))
# (slice(13042, 13847, None), slice(0, 513, None), slice(1287, 2085, None))
# box 923: 39.32 render  0.44 write
# (slice(13039, 13844, None), slice(772, 1576, None), slice(1506, 2304, None))
# (slice(13042, 13846, None), slice(0, 513, None), slice(1524, 2304, None))
# box 924: 37.95 render  0.37 write
# (slice(13031, 13836, None), slice(1337, 2143, None), slice(0, 550, None))
# (slice(13046, 13851, None), slice(187, 991, None), slice(0, 574, None))
# box 925: 39.16 render  0.39 write
# (slice(13032, 13838, None), slice(1337, 2142, None), slice(224, 1032, None))
# (slice(13046, 13850, None), slice(185, 992, None), slice(245, 1052, None))
# box 926: 38.76 render  0.47 write
# (slice(13033, 13840, None), slice(1336, 2141, None), slice(703, 1517, None))
# (slice(13043, 13849, None), slice(185, 993, None), slice(728, 1527, None))
# box 927: 41.17 render  0.45 write
# (slice(13037, 13843, None), slice(1331, 2136, None), slice(1267, 2079, None))
# (slice(13042, 13846, None), slice(186, 993, None), slice(1287, 2086, None))
# box 928: 39.58 render  0.42 write
# (slice(13039, 13843, None), slice(1330, 2134, None), slice(1510, 2304, None))
# (slice(13042, 13845, None), slice(189, 993, None), slice(1524, 2304, None))
# box 929: 40.87 render  0.48 write
# (slice(13031, 13836, None), slice(1818, 2303, None), slice(0, 549, None))
# (slice(13048, 13851, None), slice(667, 1472, None), slice(0, 574, None))
# box 930: 32.65 render  0.38 write
# (slice(13032, 13838, None), slice(1818, 2302, None), slice(224, 1032, None))
# (slice(13047, 13850, None), slice(667, 1473, None), slice(249, 1051, None))
# box 931: 35.10 render  0.38 write
# (slice(13033, 13840, None), slice(1814, 2301, None), slice(704, 1517, None))
# (slice(13044, 13849, None), slice(667, 1474, None), slice(728, 1529, None))
# box 932: 33.20 render  0.41 write
# (slice(13037, 13842, None), slice(1810, 2296, None), slice(1269, 2079, None))
# (slice(13042, 13847, None), slice(669, 1474, None), slice(1287, 2088, None))
# box 933: 34.25 render  0.43 write
# (slice(13039, 13843, None), slice(1810, 2294, None), slice(1514, 2304, None))
# (slice(13042, 13847, None), slice(671, 1474, None), slice(1524, 2304, None))
# box 934: 32.85 render  0.46 write
# (slice(13048, 13850, None), slice(1228, 2033, None), slice(0, 571, None))
# box 935: 21.36 render  0.39 write
# (slice(13047, 13850, None), slice(1230, 2033, None), slice(247, 1049, None))
# box 936: 21.11 render  0.46 write
# (slice(13045, 13849, None), slice(1231, 2033, None), slice(726, 1530, None))
# box 937: 21.27 render  0.58 write
# (slice(13044, 13848, None), slice(1230, 2033, None), slice(1287, 2089, None))
# box 938: 21.44 render  0.41 write
# (slice(13044, 13848, None), slice(1230, 2033, None), slice(1526, 2304, None))
# box 939: 21.02 render  0.39 write
# (slice(13048, 13850, None), slice(1629, 2273, None), slice(0, 570, None))
# box 940: 19.44 render  0.53 write
# (slice(13047, 13850, None), slice(1630, 2273, None), slice(246, 1049, None))
# box 941: 21.21 render  0.60 write
# (slice(13046, 13849, None), slice(1631, 2273, None), slice(726, 1530, None))
# box 942: 19.93 render  0.48 write
# (slice(13045, 13848, None), slice(1630, 2273, None), slice(1287, 2089, None))
# box 943: 20.39 render  0.58 write
# (slice(13045, 13848, None), slice(1630, 2273, None), slice(1527, 2304, None))
# box 944: 21.05 render  0.49 write
# (slice(13356, 14161, None), slice(0, 623, None), slice(0, 548, None))
# box 945: 19.49 render  0.57 write
# (slice(13357, 14162, None), slice(0, 623, None), slice(225, 1028, None))
# box 946: 21.15 render  0.63 write
# (slice(13358, 14164, None), slice(0, 623, None), slice(705, 1508, None))
# box 947: 20.97 render  0.63 write
# (slice(13360, 14166, None), slice(0, 622, None), slice(1264, 2068, None))
# box 948: 20.55 render  0.62 write
# (slice(13361, 14166, None), slice(0, 621, None), slice(1503, 2304, None))
# box 949: 20.06 render  0.56 write
# (slice(13355, 14160, None), slice(298, 1103, None), slice(0, 548, None))
# box 950: 20.71 render  0.44 write
# (slice(13355, 14161, None), slice(298, 1104, None), slice(225, 1028, None))
# box 951: 21.12 render  0.61 write
# (slice(13356, 14163, None), slice(297, 1104, None), slice(705, 1510, None))
# box 952: 20.94 render  0.65 write
# (slice(13358, 14165, None), slice(295, 1102, None), slice(1264, 2073, None))
# box 953: 21.44 render  0.66 write
# (slice(13359, 14165, None), slice(294, 1100, None), slice(1504, 2304, None))
# box 954: 20.67 render  0.51 write
# (slice(13353, 14158, None), slice(778, 1583, None), slice(0, 548, None))
# (slice(13366, 14171, None), slice(0, 513, None), slice(0, 574, None))
# box 955: 37.10 render  0.61 write
# (slice(13353, 14159, None), slice(778, 1583, None), slice(224, 1028, None))
# (slice(13366, 14169, None), slice(0, 511, None), slice(246, 1052, None))
# box 956: 39.57 render  0.53 write
# (slice(13353, 14160, None), slice(778, 1583, None), slice(703, 1514, None))
# (slice(13363, 14169, None), slice(0, 512, None), slice(727, 1530, None))
# box 957: 38.38 render  0.75 write
# (slice(13357, 14164, None), slice(773, 1580, None), slice(1264, 2077, None))
# (slice(13362, 14167, None), slice(0, 513, None), slice(1287, 2086, None))
# box 958: 39.57 render  0.55 write
# (slice(13359, 14164, None), slice(773, 1576, None), slice(1505, 2304, None))
# (slice(13362, 14166, None), slice(0, 513, None), slice(1524, 2304, None))
# box 959: 38.18 render  0.68 write
# (slice(13352, 14156, None), slice(1338, 2143, None), slice(0, 549, None))
# (slice(13366, 14171, None), slice(186, 991, None), slice(0, 574, None))
# box 960: 38.54 render  0.49 write
# (slice(13353, 14158, None), slice(1338, 2142, None), slice(224, 1032, None))
# (slice(13366, 14170, None), slice(185, 992, None), slice(246, 1052, None))
# box 961: 39.18 render  0.68 write
# (slice(13353, 14159, None), slice(1336, 2141, None), slice(703, 1516, None))
# (slice(13363, 14169, None), slice(185, 993, None), slice(729, 1528, None))
# box 962: 38.97 render  0.65 write
# (slice(13357, 14163, None), slice(1331, 2135, None), slice(1265, 2079, None))
# (slice(13362, 14167, None), slice(186, 993, None), slice(1287, 2086, None))
# box 963: 40.20 render  0.55 write
# (slice(13359, 14164, None), slice(1330, 2134, None), slice(1508, 2304, None))
# (slice(13362, 14166, None), slice(189, 993, None), slice(1524, 2304, None))
# box 964: 40.13 render  0.51 write
# (slice(13352, 14156, None), slice(1820, 2303, None), slice(0, 549, None))
# (slice(13368, 14171, None), slice(667, 1472, None), slice(0, 574, None))
# box 965: 32.29 render  0.49 write
# (slice(13353, 14158, None), slice(1817, 2302, None), slice(224, 1032, None))
# (slice(13366, 14170, None), slice(667, 1473, None), slice(249, 1051, None))
# box 966: 35.48 render  0.48 write
# (slice(13353, 14159, None), slice(1814, 2301, None), slice(704, 1516, None))
# (slice(13364, 14169, None), slice(667, 1473, None), slice(728, 1529, None))
# box 967: 33.07 render  0.63 write
# (slice(13357, 14163, None), slice(1810, 2295, None), slice(1269, 2079, None))
# (slice(13362, 14167, None), slice(669, 1473, None), slice(1287, 2089, None))
# box 968: 35.25 render  0.65 write
# (slice(13359, 14163, None), slice(1810, 2294, None), slice(1512, 2304, None))
# (slice(13362, 14167, None), slice(671, 1473, None), slice(1524, 2304, None))
# box 969: 33.15 render  0.52 write
# (slice(13368, 14170, None), slice(1228, 2032, None), slice(0, 571, None))
# box 970: 19.69 render  0.50 write
# (slice(13366, 14170, None), slice(1230, 2033, None), slice(247, 1050, None))
# box 971: 21.16 render  0.50 write
# (slice(13365, 14169, None), slice(1231, 2033, None), slice(727, 1530, None))
# box 972: 20.35 render  0.44 write
# (slice(13364, 14168, None), slice(1229, 2033, None), slice(1287, 2090, None))
# box 973: 21.58 render  0.48 write
# (slice(13364, 14168, None), slice(1229, 2033, None), slice(1526, 2304, None))
# box 974: 22.31 render  0.52 write
# (slice(13368, 14170, None), slice(1629, 2272, None), slice(0, 570, None))
# box 975: 20.64 render  0.73 write
# (slice(13367, 14170, None), slice(1630, 2273, None), slice(247, 1050, None))
# box 976: 21.55 render  0.55 write
# (slice(13366, 14169, None), slice(1631, 2273, None), slice(727, 1530, None))
# box 977: 19.87 render  0.66 write
# (slice(13365, 14168, None), slice(1630, 2273, None), slice(1287, 2090, None))
# box 978: 19.79 render  0.55 write
# (slice(13365, 14168, None), slice(1630, 2273, None), slice(1527, 2304, None))
# box 979: 20.78 render  0.81 write

# %%
import tensorstore as ts 
import zarr_io

bucket = 'sofima-test-bucket'
in_path = 'output_level_1.zarr'
out_path = 'output_level_1_rechunked.zarr'
fused = zarr_io.open_zarr_gcs(bucket, in_path)

rechunked = ts.open({
        'driver': 'zarr', 
        'dtype': 'uint16',
        'kvstore' : {
            'driver': 'gcs', 
            'bucket': bucket,
        }, 
        'create': True,
        'delete_existing': True, 
        'path': out_path, 
        'metadata': {
        'chunks': [1, 1, 128, 128, 128],
        'compressor': {
          'blocksize': 0,
          'clevel': 1,
          'cname': 'zstd',
          'id': 'blosc',
          'shuffle': 1,
        },
        'dimension_separator': '/',
        'dtype': '<u2',
        'fill_value': 0,
        'filters': None,
        'order': 'C',
        'shape': fused.shape,
        'zarr_format': 2
        }
    }).result()

rechunked[:,:,:,:,:].write(fused[:,:,:,:,:]).result()

# %% [markdown]
# Scratch Below

# %%
# SOFIMA, Low Res
cloud_storage = CloudStorage.S3
bucket = 'aind-open-data'
dataset_path = 'diSPIM_647459_2022-12-07_00-00-00/diSPIM.zarr'
downsample_exp = 2
tile_names = ['tile_X_0000_Y_0000_Z_0000_CH_0405_cam1.zarr', 
                'tile_X_0001_Y_0000_Z_0000_CH_0405_cam1.zarr']
tile_layout = np.array([[1],
                        [0]])
input_zarr = ZarrDataset(cloud_storage=cloud_storage,
                            bucket=bucket,
                            dataset_path=dataset_path, 
                            tile_names=tile_names,
                            downsample_exp=downsample_exp)

zarr_stitcher = ZarrStitcher(input_zarr, tile_layout)
cx, cy, coarse_mesh = zarr_stitcher.run_coarse_registration()
c_fine_mesh, c_fine_mesh_xy_to_index = zarr_stitcher.run_fusion_on_coarse_mesh(output_cloud_storage=output_cloud_storage,
                                        output_bucket=output_bucket,
                                        output_path=output_path,
                                        downsample_exp=2,
                                        coarse_mesh=coarse_mesh)
# Out:
# Top Id: 1, Bottom Id: 0
# Top: (0, 0), Bot: (1, 0) [ -1. 285.  -4.]

# %%
cloud_storage = CloudStorage.S3
bucket = 'aind-open-data'
dataset_path = 'diSPIM_647459_2022-12-07_00-00-00/diSPIM.zarr'
downsample_exp = 2
tile_names = ['tile_X_0000_Y_0000_Z_0000_CH_0405_cam1.zarr', 
                'tile_X_0001_Y_0000_Z_0000_CH_0405_cam1.zarr']
tile_layout = np.array([[1],
                        [0]])
input_zarr = ZarrDataset(cloud_storage=cloud_storage,
                            bucket=bucket,
                            dataset_path=dataset_path, 
                            tile_names=tile_names,
                            downsample_exp=downsample_exp)

zarr_stitcher = ZarrStitcher(input_zarr, tile_layout)
cx, cy, coarse_mesh = zarr_stitcher.run_coarse_registration()
stride_zyx = (20, 20, 20)
fine_mesh, fine_mesh_xy_to_index = zarr_stitcher.run_fine_registration(cx, cy, coarse_mesh, stride_zyx)
# Out:
# Top Id: 1, Bottom Id: 0
# Top: (0, 0), Bot: (1, 0) [ -1. 285.  -4.]
# (slice(None, None, None), slice(0, 3543, None), slice(280, 576, None), slice(0, 576, None))
# (slice(None, None, None), slice(0, 3543, None), slice(0, 296, None), slice(0, 576, None))

# %%
np.all(c_fine_mesh == fine_mesh)
# Out:
# True

# %%
id(c_fine_mesh) == id(fine_mesh)
# Out:
# False

# %%
c_fine_mesh_xy_to_index
# Out:
# {(0, 0): 0, (0, 1): 1}

# %%
fine_mesh_xy_to_index
# Out:
# {(0, 0): 0, (0, 1): 1}

# %%
cloud_storage = CloudStorage.S3
bucket = 'aind-open-data'
dataset_path = 'diSPIM_647459_2022-12-07_00-00-00/diSPIM.zarr'
downsample_exp = 2
tile_names = ['tile_X_0000_Y_0000_Z_0000_CH_0405_cam1.zarr', 
                'tile_X_0001_Y_0000_Z_0000_CH_0405_cam1.zarr']
tile_layout = np.array([[1],
                        [0]])
input_zarr = ZarrDataset(cloud_storage=cloud_storage,
                            bucket=bucket,
                            dataset_path=dataset_path, 
                            tile_names=tile_names,
                            downsample_exp=downsample_exp)

zarr_stitcher = ZarrStitcher(input_zarr, tile_layout)
cx, cy, coarse_mesh = zarr_stitcher.run_coarse_registration()
zarr_stitcher.run_fusion_on_coarse_mesh(output_cloud_storage=output_cloud_storage,
                                        output_bucket=output_bucket,
                                        output_path=output_path,
                                        downsample_exp=2,
                                        coarse_mesh=coarse_mesh)
# Out:
# Top Id: 1, Bottom Id: 0
# Top: (0, 0), Bot: (1, 0) [ -1. 285.  -4.]
# tg_box=BoundingBox(start=(0, -8, 0), size=(28, 29, 178), is_border_start=(False, False, False), is_border_end=(False, False, False))
# out_box=BoundingBox(start=(0, -160, 0), size=(560, 580, 3560), is_border_start=(False, False, False), is_border_end=(False, False, False))
# tg_box=BoundingBox(start=(0, 7, -1), size=(28, 29, 178), is_border_start=(False, False, False), is_border_end=(False, False, False))
# out_box=BoundingBox(start=(0, 716, -20), size=(560, 580, 3560), is_border_start=(False, False, False), is_border_end=(False, False, False))
# (slice(0, 519, None), slice(0, 233, None), slice(0, 540, None))
# box 0: 14.94 render  0.24 write
# (slice(0, 519, None), slice(0, 233, None), slice(0, 576, None))
# box 1: 14.73 render  0.45 write
# (slice(0, 519, None), slice(0, 294, None), slice(0, 540, None))
# box 2: 16.08 render  0.38 write
# (slice(0, 519, None), slice(0, 294, None), slice(0, 576, None))
# box 3: 17.18 render  0.67 write
# (slice(437, 1019, None), slice(0, 234, None), slice(0, 540, None))
# box 4: 15.34 render  0.24 write
# (slice(437, 1019, None), slice(0, 234, None), slice(0, 576, None))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[40], line 17
#      15 zarr_stitcher = ZarrStitcher(input_zarr, tile_layout)
#      16 cx, cy, coarse_mesh = zarr_stitcher.run_coarse_registration()
# ---> 17 zarr_stitcher.run_fusion_on_coarse_mesh(output_cloud_storage=output_cloud_storage,
#      18                                         output_bucket=output_bucket,
#      19                                         output_path=output_path,
#      20                                         downsample_exp=2,
#      21                                         coarse_mesh=coarse_mesh)
#
# Cell In[39], line 414, in ZarrStitcher.run_fusion_on_coarse_mesh(self, output_cloud_storage, output_bucket, output_path, downsample_exp, coarse_mesh, stride_zyx, parallelism)
#     408     fine_mesh[:, fine_mesh_xy_to_index[tx, ty], ...] = coarse_mesh[:, 0, ty, tx].reshape(
#     409     (dim,) + (1,) * dim)
#     411 # TEMPORARY
#     412 # return fine_mesh, fine_mesh_xy_to_index
# --> 414 self._run_fusion(output_cloud_storage,
#     415                 output_bucket,
#     416                 output_path,
#     417                 downsample_exp,
#     418                 fine_mesh,
#     419                 fine_mesh_xy_to_index,
#     420                 stride_zyx,
#     421                 parallelism)
#
# Cell In[39], line 373, in ZarrStitcher._run_fusion(self, output_cloud_storage, output_bucket, output_path, downsample_exp, fine_mesh, fine_mesh_xy_to_index, stride_zyx, parallelism)
#     371 # Feed in an empty subvol, with dimensions of sub_box.
#     372 inp_subvol = subvolume.Subvolume(np.zeros(sub_box.size[::-1], dtype=np.uint16)[None, ...], sub_box)
# --> 373 ret_subvol = renderer.process(inp_subvol)  # czyx
#     375 t_render = time.time()
#     377 # ret_subvol is a 4D CZYX volume
#
# File ~/sofima-testing/fusion.py:299, in StitchAndRender3dTiles.process(self, subvol)
#     297 ret = img
#     298 ret[norm > 0] /= norm[norm > 0]
# --> 299 ret = ret.astype(self.output_type(subvol.data.dtype))
#     301 return self.crop_box_and_data(box, ret[None, ...])
#
# File /opt/conda/envs/py311/lib/python3.11/site-packages/connectomics/volume/subvolume.py:138, in Subvolume.data(self)
#     135   """Bounding box."""
#     136   return self._bbox
# --> 138 @property
#     139 def data(self) -> np.ndarray:
#     140   """Underlying data."""
#     141   return self._data
#
# KeyboardInterrupt:

# %%
# -> Fixing fusion shape
# -> Trying a preinstalled image (which will be hard to replicate in code ocean)

# But its progress.
